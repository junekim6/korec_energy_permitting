# %% [markdown]
# ### Google Maps API
# https://developers.google.com/maps/documentation/geocoding

# %%
#This loads The built-in Python OS libary which speaks to your operating system
#And in this case we use it to retrieve a hidden environmental variable
import os
api_key = 'AIzaSyCrdX-JQoW7qYB0Ls--1Ws6_Rxt-lLYl3U'
#in terminal:
#$ echo 'export ENV_VAR=12345' >> ~/.zshenv
#see: https://apple.stackexchange.com/questions/356441/how-to-add-permanent-environment-variable-in-zsh

# %%
#I am setting up a couple variables to pass into requests' get() method
#The variable r is an object that will contain the results of the request
#and lots of information about the request
import requests
url = 'https://maps.googleapis.com/maps/api/geocode/json'
keys = {'address': '2950 Broadway, New York, NY', 'key': api_key}
r = requests.get(url,params=keys)

# %%
#This pulls out the json response from r
result_dic = r.json()

# %%
#Viewing the JSON result
result_dic
# Out:
# {'results': [{'address_components': [{'long_name': '2950',
#      'short_name': '2950',
#      'types': ['street_number']},
#     {'long_name': 'Broadway', 'short_name': 'Broadway', 'types': ['route']},
#     {'long_name': 'Manhattan',
#      'short_name': 'Manhattan',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'New York',
#      'short_name': 'New York',
#      'types': ['locality', 'political']},
#     {'long_name': 'New York County',
#      'short_name': 'New York County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'New York',
#      'short_name': 'NY',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '10027', 'short_name': '10027', 'types': ['postal_code']},
#     {'long_name': '7060',
#      'short_name': '7060',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '2950 Broadway, New York, NY 10027, USA',
#    'geometry': {'location': {'lat': 40.8076308, 'lng': -73.9636318},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 40.8090480802915,
#       'lng': -73.9624472197085},
#      'southwest': {'lat': 40.8063501197085, 'lng': -73.9651451802915}}},
#    'place_id': 'ChIJyQ3Tlj72wokREkZCjslS1Rw',
#    'plus_code': {'compound_code': 'R25P+3G New York, NY',
#     'global_code': '87G8R25P+3G'},
#    'types': ['street_address']}],
#  'status': 'OK'}

# %%
#Viewing parts of that result
result_dic['results'][0]['address_components']
# Out:
# [{'long_name': '2950', 'short_name': '2950', 'types': ['street_number']},
#  {'long_name': 'Broadway', 'short_name': 'Broadway', 'types': ['route']},
#  {'long_name': 'Manhattan',
#   'short_name': 'Manhattan',
#   'types': ['political', 'sublocality', 'sublocality_level_1']},
#  {'long_name': 'New York',
#   'short_name': 'New York',
#   'types': ['locality', 'political']},
#  {'long_name': 'New York County',
#   'short_name': 'New York County',
#   'types': ['administrative_area_level_2', 'political']},
#  {'long_name': 'New York',
#   'short_name': 'NY',
#   'types': ['administrative_area_level_1', 'political']},
#  {'long_name': 'United States',
#   'short_name': 'US',
#   'types': ['country', 'political']},
#  {'long_name': '10027', 'short_name': '10027', 'types': ['postal_code']},
#  {'long_name': '7060', 'short_name': '7060', 'types': ['postal_code_suffix']}]

# %%
result_dic['results'][0]
# Out:
# {'address_components': [{'long_name': '2950',
#    'short_name': '2950',
#    'types': ['street_number']},
#   {'long_name': 'Broadway', 'short_name': 'Broadway', 'types': ['route']},
#   {'long_name': 'Manhattan',
#    'short_name': 'Manhattan',
#    'types': ['political', 'sublocality', 'sublocality_level_1']},
#   {'long_name': 'New York',
#    'short_name': 'New York',
#    'types': ['locality', 'political']},
#   {'long_name': 'New York County',
#    'short_name': 'New York County',
#    'types': ['administrative_area_level_2', 'political']},
#   {'long_name': 'New York',
#    'short_name': 'NY',
#    'types': ['administrative_area_level_1', 'political']},
#   {'long_name': 'United States',
#    'short_name': 'US',
#    'types': ['country', 'political']},
#   {'long_name': '10027', 'short_name': '10027', 'types': ['postal_code']},
#   {'long_name': '7060',
#    'short_name': '7060',
#    'types': ['postal_code_suffix']}],
#  'formatted_address': '2950 Broadway, New York, NY 10027, USA',
#  'geometry': {'location': {'lat': 40.8076308, 'lng': -73.9636318},
#   'location_type': 'ROOFTOP',
#   'viewport': {'northeast': {'lat': 40.8090480802915,
#     'lng': -73.9624472197085},
#    'southwest': {'lat': 40.8063501197085, 'lng': -73.9651451802915}}},
#  'place_id': 'ChIJyQ3Tlj72wokREkZCjslS1Rw',
#  'plus_code': {'compound_code': 'R25P+3G New York, NY',
#   'global_code': '87G8R25P+3G'},
#  'types': ['street_address']}

# %%
result_dic['results'][0]['geometry']['location']
# Out:
# {'lat': 40.8076308, 'lng': -73.9636318}

# %% [markdown]
# ### Looping through Google Maps API with time.sleep()!!!
# Here I'm going to loop through a list of cities and get their coordinates. But I'm going to pause my loop so that I don't make too many requests too fast and upset Google.

# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_df_updated_address.csv')

# %%
import time

placeNames = df.address.tolist()
len(placeNames)
# Out:
# 1089

# %%
geometry_df = []
not_processed = []
#looping through the placeNames list
for place in placeNames:
    url = 'https://maps.googleapis.com/maps/api/geocode/json'
    keys = {'address': place, 'key': api_key}
    r = requests.get(url,params=keys)
    result_dic = r.json()
    try:
        lat = result_dic['results'][0]['geometry']['location']['lat']
        long = result_dic['results'][0]['geometry']['location']['lng']
        coords = []
        coords.append(long)
        coords.append(lat)
        mygeometry = {'place': place, 'geometry.type': 'Point','geometry.coordinates':coords}
        geometry_df.append(mygeometry)
        print(mygeometry)
        time.sleep(0.3)
    except:
        print("Not able to process:", keys['address'])
        mygeometry = {}
        geometry_df.append(mygeometry)
        not_processed.append(keys['address'])
# Out:
# {'place': '강원도 평창군 도암면횡계리', 'geometry.type': 'Point', 'geometry.coordinates': [128.7113813, 37.6758316]}
# {'place': '전남 여수시 월내동 350', 'geometry.type': 'Point', 'geometry.coordinates': [127.7322701, 34.8465274]}
# {'place': '인천시 부평구 갈산1동94', 'geometry.type': 'Point', 'geometry.coordinates': [126.7274146, 37.515326]}
# {'place': '인천시 서구 백석동 58', 'geometry.type': 'Point', 'geometry.coordinates': [126.6616801, 37.57627919999999]}
# {'place': '충남 보령시 오천면오포리 산 212', 'geometry.type': 'Point', 'geometry.coordinates': [126.5191246, 36.4007416]}
# {'place': '충남 태안군 원북면방갈리', 'geometry.type': 'Point', 'geometry.coordinates': [126.2247896, 36.8948887]}
# {'place': '충남 당진군 송악면부곡1리', 'geometry.type': 'Point', 'geometry.coordinates': [127.0089277, 36.7317626]}
# {'place': '충남 당진군 석문면교로리 산 974', 'geometry.type': 'Point', 'geometry.coordinates': [126.5096353, 37.0326652]}
# {'place': '경남 양산시 원동면대리 산 93-4', 'geometry.type': 'Point', 'geometry.coordinates': [128.9823266, 35.4245391]}
# {'place': '대전시 유성구 금고동산21', 'geometry.type': 'Point', 'geometry.coordinates': [127.3561329, 36.362216]}
# {'place': '전남 순천시 해룡면율촌 제1산단', 'geometry.type': 'Point', 'geometry.coordinates': [127.579634, 34.883407]}
# {'place': '경남 하동군 금성면가덕리 310', 'geometry.type': 'Point', 'geometry.coordinates': [127.8207435, 34.9511205]}
# {'place': '인천시 서구 백석동 58', 'geometry.type': 'Point', 'geometry.coordinates': [126.6616801, 37.57627919999999]}
# {'place': '경북 영덕군 영덕읍창포리', 'geometry.type': 'Point', 'geometry.coordinates': [129.4213426, 36.4201595]}
# {'place': '전남 광양시 금호동광양제철소 스래그처리장', 'geometry.type': 'Point', 'geometry.coordinates': [127.7361051, 34.9328653]}
# {'place': '제주시 삼양1동 900', 'geometry.type': 'Point', 'geometry.coordinates': [126.5954907, 33.5345378]}
# {'place': '제주도 남제주군 안덕면화순리 610', 'geometry.type': 'Point', 'geometry.coordinates': [126.3403647, 33.2367154]}
# {'place': '경남 양산시 원동면대리 산 93-4', 'geometry.type': 'Point', 'geometry.coordinates': [128.9823266, 35.4245391]}
# {'place': '인천시 옹진군 영흥면외리 산 168', 'geometry.type': 'Point', 'geometry.coordinates': [126.4544618, 37.2479998]}
# {'place': '대전시 대덕구 연축동산 6-2', 'geometry.type': 'Point', 'geometry.coordinates': [127.4155717, 36.3467189]}
# {'place': '경남 양산시 원동면대리 산 93', 'geometry.type': 'Point', 'geometry.coordinates': [128.9713693, 35.4407412]}
# {'place': '부산시 기장군 장안읍효암리', 'geometry.type': 'Point', 'geometry.coordinates': [129.2991326, 35.3323776]}
# {'place': '전주시 완산구 상림동산 180-6', 'geometry.type': 'Point', 'geometry.coordinates': [127.074539, 35.815511]}
# {'place': '경남 통영시 광도면안정리', 'geometry.type': 'Point', 'geometry.coordinates': [128.4060882, 34.9449106]}
# Not able to process: 인천시 서구 원창동인천 화력발전소
# {'place': '경북 예천군 하리면송월리', 'geometry.type': 'Point', 'geometry.coordinates': [128.4245023, 36.7573156]}
# {'place': '강원도 양양군 서면영덕리', 'geometry.type': 'Point', 'geometry.coordinates': [128.5292364, 38.0151898]}
# {'place': '경북 청송군 파천면신흥리', 'geometry.type': 'Point', 'geometry.coordinates': [129.038129, 36.3946384]}
# {'place': '충남 당진군 석문면교로리 산 974', 'geometry.type': 'Point', 'geometry.coordinates': [126.5096353, 37.0326652]}
# {'place': '경북 경주시 양북면봉길리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.4708845, 35.731638]}
# {'place': '인천시 서구 원창동 336', 'geometry.type': 'Point', 'geometry.coordinates': [126.6075105, 37.5114549]}
# {'place': '전북 군산시 비옹도동군장 국가산단', 'geometry.type': 'Point', 'geometry.coordinates': [126.5317163, 35.9596094]}
# {'place': '충남 보령시 오천면보령화력내', 'geometry.type': 'Point', 'geometry.coordinates': [126.5224226, 36.4383534]}
# {'place': '인천시 서구 원창동244-17외', 'geometry.type': 'Point', 'geometry.coordinates': [126.6129443, 37.5067488]}
# {'place': '경기도 이천시 호법면안평3리 산 98', 'geometry.type': 'Point', 'geometry.coordinates': [127.412489, 37.242498]}
# {'place': '경북 영양군 석보면요원리 삼의리', 'geometry.type': 'Point', 'geometry.coordinates': [129.212156, 36.563666]}
# {'place': '전북 군산시 경암동590-2', 'geometry.type': 'Point', 'geometry.coordinates': [126.7287, 35.9821405]}
# {'place': '충남 서산시 대산읍독곶리 634', 'geometry.type': 'Point', 'geometry.coordinates': [126.37117, 36.9981699]}
# {'place': '강원도 횡성군 둔내면태기리산 1-1', 'geometry.type': 'Point', 'geometry.coordinates': [128.2471963, 37.5931718]}
# {'place': '전북 고창군 흥덕면치룡리 100', 'geometry.type': 'Point', 'geometry.coordinates': [126.7113226, 35.5380886]}
# {'place': '경남 양산시 원동면대리 산 93', 'geometry.type': 'Point', 'geometry.coordinates': [128.9713693, 35.4407412]}
# {'place': '경남 밀양시 산내면삼양리 산 1-3', 'geometry.type': 'Point', 'geometry.coordinates': [129.0063704, 35.5893496]}
# {'place': '충남 보령 청소면', 'geometry.type': 'Point', 'geometry.coordinates': [126.5895468, 36.4454104]}
# {'place': '강원도 춘천 송암동', 'geometry.type': 'Point', 'geometry.coordinates': [127.6875981, 37.854583]}
# {'place': '경기 고양 백석동', 'geometry.type': 'Point', 'geometry.coordinates': [126.7888593, 37.6403518]}
# {'place': '강원 삼척 하장면', 'geometry.type': 'Point', 'geometry.coordinates': [128.9430045, 37.3495284]}
# {'place': '경북 김천 어모면', 'geometry.type': 'Point', 'geometry.coordinates': [128.1185266, 36.1804936]}
# {'place': '경북 김천 어모면', 'geometry.type': 'Point', 'geometry.coordinates': [128.1185266, 36.1804936]}
# {'place': '전남 영광 백수읍', 'geometry.type': 'Point', 'geometry.coordinates': [126.4208079, 35.28324110000001]}
# {'place': '인천 연수 동천동', 'geometry.type': 'Point', 'geometry.coordinates': [126.6783088, 37.4094099]}
# {'place': '경기 평택 오성면', 'geometry.type': 'Point', 'geometry.coordinates': [126.9802778, 37.0077109]}
# {'place': '전남 광양 금호동 640', 'geometry.type': 'Point', 'geometry.coordinates': [127.7355026, 34.91476]}
# {'place': '경북 김천 봉산면', 'geometry.type': 'Point', 'geometry.coordinates': [128.0602867, 36.1414843]}
# {'place': '전북 익산시 부송동', 'geometry.type': 'Point', 'geometry.coordinates': [126.9953047, 35.9715334]}
# {'place': '충남 당진 송악면', 'geometry.type': 'Point', 'geometry.coordinates': [126.69346, 36.9006388]}
# {'place': '경기 가평 설악면', 'geometry.type': 'Point', 'geometry.coordinates': [127.4947001, 37.6761522]}
# {'place': '경기 화성 봉담읍', 'geometry.type': 'Point', 'geometry.coordinates': [126.9502589, 37.220154]}
# {'place': '경북 울진 북면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3730649, 37.1048627]}
# {'place': '경기 부천 삼정동', 'geometry.type': 'Point', 'geometry.coordinates': [126.7678241, 37.5242118]}
# {'place': '충남 당진 석문면', 'geometry.type': 'Point', 'geometry.coordinates': [126.5908916, 36.9819022]}
# {'place': '충남 서산 대산읍', 'geometry.type': 'Point', 'geometry.coordinates': [126.4343234, 36.9395813]}
# {'place': '인천 옹진 영흥', 'geometry.type': 'Point', 'geometry.coordinates': [126.4627227, 37.2636183]}
# {'place': '경기 여주 능서면', 'geometry.type': 'Point', 'geometry.coordinates': [127.5735231, 37.3001551]}
# {'place': '대구 달서 대천동', 'geometry.type': 'Point', 'geometry.coordinates': [128.495774, 35.824871]}
# {'place': '강원 원주 지정면', 'geometry.type': 'Point', 'geometry.coordinates': [127.8401841, 37.362118]}
# {'place': '경기 포천 창수면', 'geometry.type': 'Point', 'geometry.coordinates': [127.1891285, 37.9915306]}
# {'place': '부산 강서 생곡동', 'geometry.type': 'Point', 'geometry.coordinates': [128.8800328, 35.1325238]}
# {'place': '강원 태백 창죽동', 'geometry.type': 'Point', 'geometry.coordinates': [128.9587665, 37.236246]}
# {'place': '경기 포천 창수면', 'geometry.type': 'Point', 'geometry.coordinates': [127.1891285, 37.9915306]}
# {'place': '강원 삼척 윈덕읍', 'geometry.type': 'Point', 'geometry.coordinates': [129.3432037, 37.2325164]}
# {'place': '충남 태안 원북면', 'geometry.type': 'Point', 'geometry.coordinates': [126.2571599, 36.8234084]}
# {'place': '부산 강서구', 'geometry.type': 'Point', 'geometry.coordinates': [128.9805666, 35.2122157]}
# {'place': '강원 동해시 구호동', 'geometry.type': 'Point', 'geometry.coordinates': [129.1437223, 37.480706]}
# {'place': '경기 동두천시 광암동', 'geometry.type': 'Point', 'geometry.coordinates': [127.1009159, 37.9067614]}
# {'place': '경남 어곡동', 'geometry.type': 'Point', 'geometry.coordinates': [129.0075416, 35.3972531]}
# {'place': '경북 포항시 남구', 'geometry.type': 'Point', 'geometry.coordinates': [129.3592306, 36.0086283]}
# {'place': '강원도 동해시 삼화동', 'geometry.type': 'Point', 'geometry.coordinates': [129.068103, 37.4908884]}
# {'place': '경북 영주시 평은면', 'geometry.type': 'Point', 'geometry.coordinates': [128.6758264, 36.7430181]}
# {'place': '경북 경주시 양북면', 'geometry.type': 'Point', 'geometry.coordinates': [129.4430326, 35.7910787]}
# {'place': '충남 보령시 주교면', 'geometry.type': 'Point', 'geometry.coordinates': [126.5692554, 36.3908376]}
# {'place': '전남 신안군 팔금면 원산리', 'geometry.type': 'Point', 'geometry.coordinates': [126.1143338, 34.786947]}
# {'place': '전남 신안군 팔금면 진고리', 'geometry.type': 'Point', 'geometry.coordinates': [126.157117, 34.7730806]}
# {'place': '전남 영암군 금정면 연소리', 'geometry.type': 'Point', 'geometry.coordinates': [126.780318, 34.8214605]}
# {'place': '경기 파주시 파주읍봉암리', 'geometry.type': 'Point', 'geometry.coordinates': [126.7954201, 37.8214984]}
# {'place': '서울 마포구 당인동', 'geometry.type': 'Point', 'geometry.coordinates': [126.9194445, 37.54273939999999]}
# {'place': '경북 안동시 풍산읍 괴정리', 'geometry.type': 'Point', 'geometry.coordinates': [128.536271, 36.5985998]}
# {'place': '경북 경주시 감포읍', 'geometry.type': 'Point', 'geometry.coordinates': [129.5016796, 35.8074391]}
# {'place': '경북 경주시 양남면', 'geometry.type': 'Point', 'geometry.coordinates': [129.4604091, 35.6778061]}
# {'place': '충남 태안군 원북면발전로 447-40', 'geometry.type': 'Point', 'geometry.coordinates': [126.2312041, 36.8979989]}
# {'place': '충남 당진군 송악면부곡리 564', 'geometry.type': 'Point', 'geometry.coordinates': [126.7813551, 36.9571468]}
# {'place': '경북 경주시 천군동1516번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.2696275, 35.8193388]}
# {'place': '경북 영양군 영양읍', 'geometry.type': 'Point', 'geometry.coordinates': [129.1141518, 36.6670434]}
# {'place': '부산 강서구 신호동', 'geometry.type': 'Point', 'geometry.coordinates': [128.8807923, 35.09025]}
# {'place': '부산 강서구 신호동', 'geometry.type': 'Point', 'geometry.coordinates': [128.8807923, 35.09025]}
# {'place': '경남 양산시 원동면', 'geometry.type': 'Point', 'geometry.coordinates': [128.9187874, 35.3646853]}
# {'place': '경기도 화성시 향남읍', 'geometry.type': 'Point', 'geometry.coordinates': [126.9199753, 37.1321066]}
# {'place': '울산 남구 남화동', 'geometry.type': 'Point', 'geometry.coordinates': [129.3767054, 35.4761122]}
# {'place': '경기도 평택시 포승면', 'geometry.type': 'Point', 'geometry.coordinates': [126.8852807, 36.982824]}
# {'place': '전남 해남군 황산면원호리 435-1외 5필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4869616, 34.5680133]}
# {'place': '전남 영암군 삼호읍삼포리 1895-8', 'geometry.type': 'Point', 'geometry.coordinates': [126.3902632, 34.7398737]}
# {'place': '경기도 안산시 초지동MTV5공구 BL 103-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.8085765, 37.3246446]}
# {'place': '서울시 강남구 논현로 508서울시 영등포구여의도동35-6', 'geometry.type': 'Point', 'geometry.coordinates': [127.0372776, 37.5018592]}
# {'place': '경기도 오산시 누읍동332', 'geometry.type': 'Point', 'geometry.coordinates': [127.0558201, 37.140655]}
# {'place': '충남 서산시 대산읍독곶리 411-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.3540793, 37.0044]}
# {'place': '강원도 태백시 창죽동산63번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.9583529, 37.2462236]}
# {'place': '충남 당진시 석문면교로3리 1026외', 'geometry.type': 'Point', 'geometry.coordinates': [126.5908916, 36.9819022]}
# {'place': '대전시 대덕구 신일서로68번길 71', 'geometry.type': 'Point', 'geometry.coordinates': [127.403595, 36.4345023]}
# {'place': '경기도 평택시 죽백동334-3', 'geometry.type': 'Point', 'geometry.coordinates': [127.1211621, 37.0100041]}
# {'place': '전남 해남군 황산면호동리 909-21', 'geometry.type': 'Point', 'geometry.coordinates': [126.4328595, 34.5542521]}
# {'place': '전남 해남군 황산면한자리726,752-1,747및호동리968-6', 'geometry.type': 'Point', 'geometry.coordinates': [126.437281, 34.5510899]}
# {'place': '경기도 하남시 풍산동일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1864773, 37.5494849]}
# {'place': '전북 군산시 소룡동53-8', 'geometry.type': 'Point', 'geometry.coordinates': [126.6401594, 35.977753]}
# {'place': '경기도 시흥시 정왕동시화공단 2바 101', 'geometry.type': 'Point', 'geometry.coordinates': [126.7271088, 37.34860159999999]}
# {'place': '강원도 원주시 지정면신평리 420-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.8898361, 37.3724899]}
# {'place': '충북 청원군 옥산면국사리', 'geometry.type': 'Point', 'geometry.coordinates': [127.3744217, 36.687463]}
# {'place': '경기도 화성시 석우동39,동탄면 방교리 634', 'geometry.type': 'Point', 'geometry.coordinates': [127.0927885, 37.1764742]}
# {'place': '경남 진주시 남강로1317길 24', 'geometry.type': 'Point', 'geometry.coordinates': [128.0974023, 35.1784006]}
# {'place': '경기도 안산시 초지동672', 'geometry.type': 'Point', 'geometry.coordinates': [126.794652, 37.2954745]}
# {'place': '경기도 하남시 학암동일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1616155, 37.4776989]}
# {'place': '경기도 부천시 오정구삼정동 363-3', 'geometry.type': 'Point', 'geometry.coordinates': [126.7637195, 37.5220107]}
# {'place': '경기도 이천시 대월면초지리 57', 'geometry.type': 'Point', 'geometry.coordinates': [127.5017476, 37.2361558]}
# {'place': '전남 여수시 월화동144-16 화치동 1293', 'geometry.type': 'Point', 'geometry.coordinates': [127.6436963, 34.810578]}
# {'place': '전남 여수시 산단중앙로 145전북 군산시 비응도동 31', 'geometry.type': 'Point', 'geometry.coordinates': [127.6700512, 34.8322216]}
# {'place': '전북 군산시새만금산업단지내', 'geometry.type': 'Point', 'geometry.coordinates': [126.5870503, 35.9474649]}
# {'place': '경북 청송군 현서면무계리 산 11', 'geometry.type': 'Point', 'geometry.coordinates': [128.987596, 36.2210961]}
# {'place': '강원도 평창군 미탄면회동리,평안리정선군 정선읍 회동리', 'geometry.type': 'Point', 'geometry.coordinates': [128.4849847, 37.3761593]}
# {'place': '경기도 포천시 신북면신평리 220-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.2280342, 37.9580262]}
# {'place': '경기도 안산시 단원구초지동 661', 'geometry.type': 'Point', 'geometry.coordinates': [126.7994948, 37.2979683]}
# {'place': '경북 구미시 공단2동291', 'geometry.type': 'Point', 'geometry.coordinates': [128.3724286, 36.0970442]}
# {'place': '충청남도 부여군 장암면석동리 산42-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.8920177, 36.240187]}
# {'place': '충북 단양군 매포읍매포리 270', 'geometry.type': 'Point', 'geometry.coordinates': [128.3341036, 37.0156586]}
# {'place': '시흥 장현 목감지구내일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.8572641, 37.3845831]}
# {'place': '경기도 시흥시 정왕동1771-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.7172871, 37.3628905]}
# {'place': '경남 거제시 일운면소동리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.6859815, 34.8412498]}
# {'place': '전남 신안군 자은면백산리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.0100859, 34.8772532]}
# {'place': '충북 제천시 송학면입석리 289', 'geometry.type': 'Point', 'geometry.coordinates': [128.3019418, 37.2051238]}
# {'place': '전남 고흥군 금산면어적리 264', 'geometry.type': 'Point', 'geometry.coordinates': [127.1418022, 34.4435042]}
# {'place': '전남 고흥군 대서면남정리 2431-26', 'geometry.type': 'Point', 'geometry.coordinates': [127.242915, 34.7674097]}
# {'place': '경북 경주시 강동면왕신리 산46-1', 'geometry.type': 'Point', 'geometry.coordinates': [129.3124967, 35.9625481]}
# {'place': '경북 경주시 천북면화산리 1180-21', 'geometry.type': 'Point', 'geometry.coordinates': [129.2785236, 35.93498700000001]}
# {'place': '충남 천안시 청당동청수8로 54', 'geometry.type': 'Point', 'geometry.coordinates': [127.1603383, 36.7878755]}
# {'place': '광주광역시광주전남혁신도시내', 'geometry.type': 'Point', 'geometry.coordinates': [126.8526012, 35.1595454]}
# {'place': '충남 당진군 송악면부곡공단로 241', 'geometry.type': 'Point', 'geometry.coordinates': [126.7813551, 36.9571468]}
# {'place': '경기도 화성시 장안면노진리 16', 'geometry.type': 'Point', 'geometry.coordinates': [126.8199324, 37.0544233]}
# {'place': '인천시 서구 원창동437-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.6090037, 37.5084604]}
# {'place': '대구시 달성군 하빈면동곡리', 'geometry.type': 'Point', 'geometry.coordinates': [128.4152721, 35.8680476]}
# {'place': '강원도 정선군 고한읍고한리 산216-1 등지', 'geometry.type': 'Point', 'geometry.coordinates': [128.8839494, 37.1828442]}
# {'place': '경기도 남양주시별내3로 391 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1147453, 37.6669626]}
# {'place': '충남 당진군 석문면삼봉리, 고대면 성산리', 'geometry.type': 'Point', 'geometry.coordinates': [126.5680393, 36.9803517]}
# {'place': '전북 군산시 소룡동53-8 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.6401594, 35.977753]}
# {'place': '경기도 안산시 단원구초지동 672', 'geometry.type': 'Point', 'geometry.coordinates': [126.794652, 37.2954745]}
# {'place': '강원도 강릉시 강동면대동리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9541928, 37.7280308]}
# {'place': '경남 고성군 하이면덕호리 880번지 외', 'geometry.type': 'Point', 'geometry.coordinates': [128.1164472, 34.9149767]}
# {'place': '경남 진주시 이반성면장안리 1081-2외 38필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.337188, 35.1913692]}
# {'place': '경북 청송군 현서면무계리 산11번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.987596, 36.2210961]}
# {'place': '충남 아산시 인주면금성리 123', 'geometry.type': 'Point', 'geometry.coordinates': [126.8731324, 36.8453593]}
# {'place': '경남 거창군 신원면덕산리 산57번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.9162229, 35.592114]}
# {'place': '전남 나주시 영산동 664-1292필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.7457833, 35.0046214]}
# {'place': '경기도 여주군 북내면외룡리 366', 'geometry.type': 'Point', 'geometry.coordinates': [127.6583791, 37.3615969]}
# {'place': '전북 군산시 외항로1222', 'geometry.type': 'Point', 'geometry.coordinates': [126.5381948, 35.9543892]}
# {'place': '전남 해남군 송지면학가리 324-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.5055214, 34.3993809]}
# {'place': '전남 신안군 비금면구림리 39-10', 'geometry.type': 'Point', 'geometry.coordinates': [125.9489141, 34.7580286]}
# {'place': '경기도 하남시 학암동 일원(사업지구 내)', 'geometry.type': 'Point', 'geometry.coordinates': [127.1616155, 37.4776989]}
# {'place': '울산시 남구 횡성동처용로 718 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3562888, 35.4647551]}
# {'place': '전남 무안군 운남면연리 및 성내리 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3359034, 34.9544622]}
# {'place': '충남 당진시 석문면난지도리 183 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.4335439, 37.051032]}
# {'place': '강원도 삼척시 적노동일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.1770184, 37.4147184]}
# {'place': '전북 부안군 위도 및전남 영광군 안마군도', 'geometry.type': 'Point', 'geometry.coordinates': [126.5119874, 35.2771719]}
# {'place': '경남 통영시 광도면 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4068799, 34.8996122]}
# {'place': '경기도 포천시 신북면계류리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1766576, 37.9499243]}
# {'place': '울산시 남구 매암동 29', 'geometry.type': 'Point', 'geometry.coordinates': [129.3830042, 35.5106347]}
# {'place': '서울시 강서구 양천로201번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.8263719, 37.5804823]}
# {'place': '경기도 안양시 동안구부림로 100', 'geometry.type': 'Point', 'geometry.coordinates': [126.9669263, 37.3941135]}
# {'place': '전남 신안군 자은면백산리 271번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [125.9974536, 34.8779107]}
# {'place': '전남 해남군 화원면 구림리일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3135973, 34.7367405]}
# {'place': '충남 서산시 대산읍기은리 628-6 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3804953, 36.9776181]}
# {'place': '제주시 애월읍 어음리산 68-4번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3624805, 33.3843631]}
# {'place': '경북 봉화군 봉성면외삼리 산124외 12필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.7861061, 36.9039601]}
# {'place': '세종시 부강면 부강리산23 육군종합보급창고', 'geometry.type': 'Point', 'geometry.coordinates': [127.3758169, 36.5336931]}
# {'place': '전남 나주시 영산동664-1 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.7464887, 35.0046287]}
# {'place': '전남 나주시 영산동664-1 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.7464887, 35.0046287]}
# {'place': '전남 나주시 영산동664-1 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.7464887, 35.0046287]}
# {'place': '울산광역시 울주군서생면 신암리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3169375, 35.3486589]}
# {'place': '충남 서천군 마량리일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.4973423, 36.1409666]}
# {'place': '울산시 울주군 온산읍신암리 360', 'geometry.type': 'Point', 'geometry.coordinates': [129.3445913, 35.4423929]}
# {'place': '경북 고령군 다산면송곡리 1049-2,3번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.3861703, 35.7933228]}
# {'place': '충남 예산군 삽교읍1-21', 'geometry.type': 'Point', 'geometry.coordinates': [126.7393823, 36.6878955]}
# {'place': '경남 진주시 이반성면장안리 1081-2외38필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.337188, 35.1913692]}
# {'place': '전남 영암군 삼호읍삼포리 1949번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3902632, 34.7398737]}
# {'place': '충남 당진시 신평면매산리 164-8', 'geometry.type': 'Point', 'geometry.coordinates': [126.7948823, 36.9157102]}
# {'place': '강원도 강릉시 강동면임곡리 외', 'geometry.type': 'Point', 'geometry.coordinates': [128.9612013, 37.6641691]}
# {'place': '강원도 태백시 하사미동산 220-3 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.990465, 37.292041]}
# {'place': '충남 논산시 은진면시묘리 470-1외 11필지', 'geometry.type': 'Point', 'geometry.coordinates': [127.1323682, 36.1418325]}
# {'place': '서울시 강동구 강일동227-1외', 'geometry.type': 'Point', 'geometry.coordinates': [127.1660937, 37.5683886]}
# {'place': '전북 전주시 덕진구팔복로 59', 'geometry.type': 'Point', 'geometry.coordinates': [127.0985108, 35.8483399]}
# {'place': '강원도 춘천시 동산면봉명리(동춘천산업단지)', 'geometry.type': 'Point', 'geometry.coordinates': [127.777106, 37.76696099999999]}
# {'place': '인천시 남구 도화동 825', 'geometry.type': 'Point', 'geometry.coordinates': [126.6605786, 37.4803113]}
# {'place': '강원도 삼척시 동양길20(사직동)', 'geometry.type': 'Point', 'geometry.coordinates': [129.1762952, 37.4259827]}
# {'place': '대구시 달성군 논공읍본리리 29-55 산단내', 'geometry.type': 'Point', 'geometry.coordinates': [128.4601957, 35.7406053]}
# {'place': '전남 완도군 신지면월양리 산20-1일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.849492, 34.3160841]}
# {'place': '전남 영광군 백수읍상사리 및 하사리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3558487, 35.2625367]}
# {'place': '전남 영광군 백수읍 약수리및 지산리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3954744, 35.2715903]}
# {'place': '강원도 평창군 대관령면횡계리 산1-1', 'geometry.type': 'Point', 'geometry.coordinates': [128.7209909, 37.7031357]}
# {'place': '전남 고흥군 대서면남정리 2431 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.242915, 34.7674097]}
# {'place': '서울시 강동구 고덕동35-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.1634514, 37.5683014]}
# {'place': '전북 군산시새만금산업단지 내', 'geometry.type': 'Point', 'geometry.coordinates': [126.5870503, 35.9474649]}
# {'place': '대구혁신도시', 'geometry.type': 'Point', 'geometry.coordinates': [128.601445, 35.8714354]}
# {'place': '경기도양주신도시(옥정.회천)', 'geometry.type': 'Point', 'geometry.coordinates': [127.0921414, 37.8219239]}
# {'place': '전남 여수시여수산단4로 58', 'geometry.type': 'Point', 'geometry.coordinates': [127.6862811, 34.8341834]}
# {'place': '충남 아산시 배방읍 장재리672-1번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.0915493, 36.7989443]}
# {'place': '충남 태안군 안면읍중장리 425-60 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3832622, 36.4866369]}
# {'place': '충남 부여군 세도면사산리 594 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.9506547, 36.2133201]}
# {'place': '충남 서산시 해미면언암리 514-3 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4925246, 36.7261016]}
# {'place': '충남 서산시 해미면언암리 500-1 등지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4939895, 36.7228554]}
# {'place': '경기도 평택시 포승읍내기리 608-17', 'geometry.type': 'Point', 'geometry.coordinates': [126.8659301, 36.977222]}
# {'place': '경북 영양군 영양읍무창리,무학리,기산리 및수비면 송하리 등지', 'geometry.type': 'Point', 'geometry.coordinates': [129.1882857, 36.6778522]}
# {'place': '충남 아산시 배방읍장재리 672-1 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.0915493, 36.7989443]}
# {'place': '경남 양산시 상북면공원로 305-391 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.0510193, 35.4140163]}
# {'place': '경북 영양군 영양읍양구리, 석보면 홍계리', 'geometry.type': 'Point', 'geometry.coordinates': [129.176671, 36.5995907]}
# {'place': '부산 강서구르노삼성대로 61 지붕', 'geometry.type': 'Point', 'geometry.coordinates': [128.8760573, 35.0942462]}
# {'place': '전남 영광군 염산면봉남리 1100번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3403742, 35.1989907]}
# {'place': '강원도 강릉시 강동면임곡리 21', 'geometry.type': 'Point', 'geometry.coordinates': [128.9906192, 37.6957382]}
# {'place': '울산시 울주군 삼남면상천리 101-1일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.1112252, 35.5283453]}
# {'place': '세종시 장군면 봉안리160-13', 'geometry.type': 'Point', 'geometry.coordinates': [127.2272144, 36.496559]}
# {'place': '경기도 파주시 월롱면덕은리 1271 건물지붕', 'geometry.type': 'Point', 'geometry.coordinates': [126.7700657, 37.810485]}
# {'place': '대구시 서구 와룡로87길 92(이현동)', 'geometry.type': 'Point', 'geometry.coordinates': [128.5335922, 35.8754384]}
# {'place': '인천시 동구 송현3동147 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.642656, 37.4926237]}
# {'place': '경기도 광명시 자경로17', 'geometry.type': 'Point', 'geometry.coordinates': [126.8909804, 37.42296839999999]}
# {'place': '경기도 하남시 풍산동113-19일원 하남미사', 'geometry.type': 'Point', 'geometry.coordinates': [127.1864211, 37.5517187]}
# {'place': '충남  부여군  양화면  송정리 산11,  산12-1,  185-1,    185-4', 'geometry.type': 'Point', 'geometry.coordinates': [126.8343199, 36.1348486]}
# {'place': '충남  부여군  옥산면  상기리 산49-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.7184591, 36.2268137]}
# {'place': '충남  부여군  홍산면  상천리 산70-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.7504424, 36.2423212]}
# {'place': '전남  해남군  황산면  원호리 435-92,435-98', 'geometry.type': 'Point', 'geometry.coordinates': [126.4875799, 34.569675]}
# {'place': '전남  곡성군  겸면  곡순로 1672번지  32-36(상덕리    515)', 'geometry.type': 'Point', 'geometry.coordinates': [127.1917635, 35.2596267]}
# {'place': '전남  보성군  보성읍  봉산리, 옥평리,  득량면  정흥리    일대(봉화산일대)', 'geometry.type': 'Point', 'geometry.coordinates': [127.1255443, 34.7470393]}
# {'place': '경북  울진군  기성면,  원남면 현종산  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.4038889, 36.8630556]}
# {'place': '경북  김천시  공단3길  64(응명동)', 'geometry.type': 'Point', 'geometry.coordinates': [128.1311698, 36.1525931]}
# {'place': '경기  평택시  포승읍  남양만로 175-2', 'geometry.type': 'Point', 'geometry.coordinates': [126.7981862, 37.0072973]}
# {'place': '강원  원주시  문막읍  원문로 2047(반계리    2262-5,6,7)일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.7844132, 37.27574140000001]}
# {'place': '경북  구미시  임수로  24번길 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4041758, 36.1137531]}
# {'place': '경기  안산시  단원구  첨단로 267번길  31', 'geometry.type': 'Point', 'geometry.coordinates': [126.7518342, 37.3066276]}
# {'place': '전남  영광군  법성면  입암리 산34번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.4506211, 35.3334935]}
# {'place': '울산시  북구  대안동  산288-1', 'geometry.type': 'Point', 'geometry.coordinates': [129.381803, 35.6373204]}
# {'place': '강원  고성군  간성읍  흘리  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.3826076, 38.2684351]}
# {'place': '전남  신안군  자은면  고장리 산224-13  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.0138548, 34.9068822]}
# {'place': '인천시  남구  학익동  723번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.669278, 37.4380623]}
# {'place': '인천시  남구  학익동  723번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.669278, 37.4380623]}
# {'place': '인천시  남구  학익동  723번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.669278, 37.4380623]}
# {'place': '전남  해남군  황산면  한자리 23-4외  7필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4533585, 34.5404768]}
# {'place': '전남  해남군  황산면  한자리 23-11외  3필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4603158, 34.5411443]}
# {'place': '충남  태안군  안면읍  창기리 209-328,  209-330번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3665878, 36.5890999]}
# {'place': '서울시  강서구  마곡동  72', 'geometry.type': 'Point', 'geometry.coordinates': [126.8316893, 37.5742712]}
# {'place': '전남  보성군  미력면  덕림리 산13-3(임),  4-1(전)', 'geometry.type': 'Point', 'geometry.coordinates': [127.1173911, 34.7935488]}
# {'place': '울산시  북구  대안동  산288-1, 산79,  산78-1,  산78', 'geometry.type': 'Point', 'geometry.coordinates': [129.381803, 35.6373204]}
# {'place': '경북  포항시  남구  호동  39-3', 'geometry.type': 'Point', 'geometry.coordinates': [129.3922316, 35.9834386]}
# {'place': '서울시  마포구  양화로  151(동교동)', 'geometry.type': 'Point', 'geometry.coordinates': [126.9228523, 37.5578024]}
# {'place': '충남  서천군  서면  신합리 311-1', 'geometry.type': 'Point', 'geometry.coordinates': [126.5548403, 36.1423411]}
# {'place': '충남  보령시  성주면  개화리 산30', 'geometry.type': 'Point', 'geometry.coordinates': [126.6444146, 36.3019595]}
# {'place': '충남  보령시  성주면  개화리 산30', 'geometry.type': 'Point', 'geometry.coordinates': [126.6444146, 36.3019595]}
# {'place': '경기  양주시  남면  상수리 247,  247-1,  247-2,    248, 248-3', 'geometry.type': 'Point', 'geometry.coordinates': [126.9955971, 37.8632735]}
# {'place': '전북  군산시  비응도동  21,  19, 22,  23,    24,,35번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.5290799, 35.9502782]}
# {'place': '강원도  평창군  대관령면  횡계리  산178,  188-1,    188-10, 188-11,  1-134', 'geometry.type': 'Point', 'geometry.coordinates': [128.7209909, 37.7031357]}
# {'place': '전북  남원시  광치동  산7번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.388053, 35.4417872]}
# {'place': '충남  부여군  은산면  가중리 산10-26', 'geometry.type': 'Point', 'geometry.coordinates': [126.8399033, 36.3047454]}
# {'place': '경기  양주시  남면  상수리  산112-11,  산113', 'geometry.type': 'Point', 'geometry.coordinates': [126.9775128, 37.8708033]}
# {'place': '경기  양주시  남면  상수리  산112-11', 'geometry.type': 'Point', 'geometry.coordinates': [126.9775128, 37.8708033]}
# {'place': '경기  양주시  남면  상수리  산112-11', 'geometry.type': 'Point', 'geometry.coordinates': [126.9775128, 37.8708033]}
# {'place': '경기  포천시  신북면  청신로 1897(신평리  480-3번지)', 'geometry.type': 'Point', 'geometry.coordinates': [127.2045068, 37.9386342]}
# {'place': '광주광역시  광산구  수완동 1149', 'geometry.type': 'Point', 'geometry.coordinates': [126.8297814, 35.19685190000001]}
# {'place': '광주  서구  치평동 766-2 번지  외  28필지   광주제1하수종말처리장  구조물  상부', 'geometry.type': 'Point', 'geometry.coordinates': [126.8299501, 35.1575799]}
# {'place': '충남  서산시  고북면  신정리 726-19외 9필지(건물 7동   포함)  (해미비행장內)', 'geometry.type': 'Point', 'geometry.coordinates': [126.4953374, 36.6889275]}
# {'place': '전남  여수시  율촌면  율촌 제1산업단지', 'geometry.type': 'Point', 'geometry.coordinates': [127.578106, 34.8996486]}
# {'place': '충북  청주시  청원구  북이면 신대석성로  253-4', 'geometry.type': 'Point', 'geometry.coordinates': [127.5192529, 36.7464716]}
# {'place': '충남  서천군  장항읍  원수리 450-12번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.7221482, 36.0087855]}
# {'place': '경북  영양군  영양읍  무창리 산62-36,  3-2,  110,  108', 'geometry.type': 'Point', 'geometry.coordinates': [129.2164881, 36.6180468]}
# {'place': '포항시  북구  신광면  냉수리 산63,  62,  61,  17,  16-1,  16, 15,  14,  8,  7,  흥해읍    매산 리  산84,  82,  흥해읍  학천리  산1-13', 'geometry.type': 'Point', 'geometry.coordinates': [129.2754707, 36.0854411]}
# {'place': '경남남해군서면노구리산98,산99-2번지남상리산60-2,산60-3번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.850141, 34.8546853]}
# {'place': '제주특별자치도  제주시  구좌읍  덕천리  산  82', 'geometry.type': 'Point', 'geometry.coordinates': [126.7356547, 33.4806289]}
# {'place': '강원  정선군  고한읍  고한리 산216-1  등지', 'geometry.type': 'Point', 'geometry.coordinates': [128.8839494, 37.1828442]}
# {'place': '부산시  기장군  정관면  산단1로  83', 'geometry.type': 'Point', 'geometry.coordinates': [129.1783001, 35.3148842]}
# {'place': '부산시  기장군  정관면  산단1로  83', 'geometry.type': 'Point', 'geometry.coordinates': [129.1783001, 35.3148842]}
# {'place': '부산시  강서구  화전산단1로  63번길  10(화전동)', 'geometry.type': 'Point', 'geometry.coordinates': [128.875261, 35.1016291]}
# {'place': '전남  화순군  도암면  우치리 산89-1,  청풍면  백운리  산132-1,  이만리  산165', 'geometry.type': 'Point', 'geometry.coordinates': [126.918017, 34.8701236]}
# {'place': '강원  태백시  통동  산69,  황지동  산173-1', 'geometry.type': 'Point', 'geometry.coordinates': [128.9789425, 37.1867588]}
# {'place': '강원  평창군  봉평면  진조리 산80-1,  횡성군  둔내면  삽 교리  산1-3', 'geometry.type': 'Point', 'geometry.coordinates': [128.3061851, 37.5610736]}
# {'place': '경남  통영시  광도면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4068799, 34.8996122]}
# {'place': '강원  강릉시  옥계면  산계리 8번지(라파즈한라시멘트  공장부지  내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.008498, 37.589326]}
# {'place': '서울시  마포구  상암동 481-6(월드컵공원내)', 'geometry.type': 'Point', 'geometry.coordinates': [126.8935007, 37.5638735]}
# {'place': '전남  여수시  여수국가산단 내(여수산단2로  46-51,  월하동)', 'geometry.type': 'Point', 'geometry.coordinates': [127.6607226, 34.8091104]}
# {'place': '경남  산청군  신등면  모례리 산78-1,  산청읍  범학리  산31,  척지리  산134', 'geometry.type': 'Point', 'geometry.coordinates': [127.9547734, 35.3942834]}
# {'place': '경남  산청군  신등면  율현리 산166,  산169,  척지리  산17', 'geometry.type': 'Point', 'geometry.coordinates': [127.9525195, 35.4213444]}
# {'place': '경북  청송군  안덕면  노래리 산68-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.0077296, 36.3755631]}
# {'place': '충남  천안시  청당동  청수8로  56번길', 'geometry.type': 'Point', 'geometry.coordinates': [127.1613093, 36.7870828]}
# {'place': '전남  장흥군  해당리  장흥 바이오  식품산업단지내', 'geometry.type': 'Point', 'geometry.coordinates': [126.9370673, 34.6919321]}
# {'place': '경남  양산시  상북면  내석리 산237,  산238,  산239', 'geometry.type': 'Point', 'geometry.coordinates': [128.994729, 35.4417093]}
# {'place': '경 남 산 청 군 금 서 면 특 리 산79-1,산79-2,자혜리산7-1일대', 'geometry.type': 'Point', 'geometry.coordinates': [128.0098139, 35.010101]}
# {'place': '전남  강진군  도암면  석문리 산  215,  산194-3  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.7111629, 34.5310617]}
# {'place': '경북  김천시  어모면  산업단지로  39번지  공장지붕', 'geometry.type': 'Point', 'geometry.coordinates': [128.116879, 36.161571]}
# {'place': '경북  김천시  어모면  옥계리 산214번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.0787591, 36.2301746]}
# {'place': '전북  남원시  광치동  산51-1외  9필지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.3956179, 35.46593]}
# {'place': '경북  울진군  북면  울진북로 2040', 'geometry.type': 'Point', 'geometry.coordinates': [129.3730611, 37.09877]}
# {'place': '울산시  남구  장생포로  285번길', 'geometry.type': 'Point', 'geometry.coordinates': [129.3739645, 35.5140251]}
# {'place': '충남  청양군  정산면  역촌리 701-1,  703-1,  705-3번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.9498301, 36.4209824]}
# {'place': '부산광역시  해운대구  해운대로  896', 'geometry.type': 'Point', 'geometry.coordinates': [129.1848351, 35.1739926]}
# {'place': '전남  무안군  청계면  영산로 1958-98', 'geometry.type': 'Point', 'geometry.coordinates': [126.4398904, 34.9299467]}
# {'place': '경남  함안군  대산면  부목리 169', 'geometry.type': 'Point', 'geometry.coordinates': [128.4694479, 35.36249980000001]}
# {'place': '전남  신안군  압해면  가룡리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.301154, 34.9066445]}
# {'place': '전남  장성군  삼계면  부성리 산129-3,  산129-2,  신기리 산141-2,  화산리  산136-1, 산137-8,    삼서면  학성리  산96-2', 'geometry.type': 'Point', 'geometry.coordinates': [126.6130309, 35.299998]}
# {'place': '전남  고흥군  호형리  산126, 산127,  산128,  산129,  산171-1,  산171-3,  산171-4, 산171-5,  산171-6,  등암리 산6,  포두면  봉림리  산34, 산36,  산36-1,  산130-1,  풍양면  율치리  산151', 'geometry.type': 'Point', 'geometry.coordinates': [127.3065763, 34.5785116]}
# {'place': '울산시  울주군  온산읍  원산로  59', 'geometry.type': 'Point', 'geometry.coordinates': [129.3499243, 35.4123051]}
# {'place': '충남  홍성군  구항면  지정리 107-11,  산24', 'geometry.type': 'Point', 'geometry.coordinates': [126.638396, 36.5519987]}
# {'place': '강원  고성군  수동면,  현내면, 간성읍,  거진읍  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4525014, 38.4362262]}
# {'place': '전북  군산시  새만금  매립지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.587035, 35.9474822]}
# {'place': '제주시  삼양동  900번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.596692, 33.5056199]}
# {'place': '부산시  강서구  명지동 607-641', 'geometry.type': 'Point', 'geometry.coordinates': [128.9063123, 35.1130958]}
# {'place': '경북  안동시  길안면  백자리 산97번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.8661746, 36.3907017]}
# {'place': '경기  평택시  고덕면  해창4길  64-15  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.0131919, 37.0272752]}
# {'place': '충북  청주시  흥덕구  옥산면 호죽리  907외908', 'geometry.type': 'Point', 'geometry.coordinates': [127.3725868, 36.702395]}
# {'place': '제주  제주시  월산남길  312(해안동)', 'geometry.type': 'Point', 'geometry.coordinates': [126.4718292, 33.4475848]}
# {'place': '강원  횡성군  횡성읍  조곡리 3-2번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.0293088, 37.4947916]}
# {'place': '경북  영천시  고경면  상계로 178-18', 'geometry.type': 'Point', 'geometry.coordinates': [129.0996058, 36.0055718]}
# {'place': '경기  화성시  송산면  마산리 416-15번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.6779365, 37.225302]}
# {'place': '강원  태백시  창죽동  9-167외  8필지  화전동  143-26외 1필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.9602141, 37.2236723]}
# {'place': '전남  신안군  압해면  가룡리 일원(해상  포함)', 'geometry.type': 'Point', 'geometry.coordinates': [126.301154, 34.9066445]}
# {'place': '전남  여수시  여수산단로  남해화학  부지  내', 'geometry.type': 'Point', 'geometry.coordinates': [127.75078, 34.8528969]}
# {'place': '강원  정선군  고한읍  고한리 산216-1  등지', 'geometry.type': 'Point', 'geometry.coordinates': [128.8839494, 37.1828442]}
# {'place': '충북  천안시  서북구  차암동 14-4  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1151654, 36.8575236]}
# {'place': '전북  군산시  비응도동  36', 'geometry.type': 'Point', 'geometry.coordinates': [126.5341796, 35.9480587]}
# {'place': '경기  양주시  옥정동  840-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.0793277, 37.8164517]}
# {'place': '전남  장흥군  부산면  지천리 산22', 'geometry.type': 'Point', 'geometry.coordinates': [126.9062972, 34.76421670000001]}
# {'place': '전남  해남군  송지면  통호리 산  98  등  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.5524058, 34.334182]}
# {'place': '경북  포항시  남구  오천읍 진전리  산88-1번지', 'geometry.type': 'Point', 'geometry.coordinates': [129.4039238, 35.8669399]}
# {'place': '전남  목포시  대양동  797번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3984875, 34.8338694]}
# {'place': '대구시  동구  율암동  산5번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.6989164, 35.88592430000001]}
# {'place': '광주시  서구  매월1로  50-4', 'geometry.type': 'Point', 'geometry.coordinates': [126.8552691, 35.1109797]}
# {'place': '경북  포항시  남구  장기면 두원리  산162임,  산162-1임, 산162-2임,  계원리  산87  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.4954784, 35.85525]}
# {'place': '강원  철원군  근남면  육단리 산88-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.5162673, 38.2200201]}
# {'place': '경북  김천시  대광동  797번지  일대', 'geometry.type': 'Point', 'geometry.coordinates': [128.1440719, 36.1371455]}
# {'place': '전남  무안군  운남면  내리 산39번지,  714-5,  711-29, 산50,  산41-1,  산107-8', 'geometry.type': 'Point', 'geometry.coordinates': [126.3122803, 34.9861732]}
# {'place': '경남  양산시  원동면  대리 산90-1,  산16-1,  선리  산1-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9846345, 35.457992]}
# {'place': '경북  군위군  고로면  화북리 산229-1,  1254-4,5,6,  영천시 신녕면  화남리  산64/가천리   산18-1,산23', 'geometry.type': 'Point', 'geometry.coordinates': [128.7772619, 36.1003197]}
# {'place': '제주시  한림읍  금악리  산23번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3461914, 33.3489594]}
# {'place': '경북  청송군  현서면  무계리 산11번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.987596, 36.2210961]}
# {'place': '여주시  강천면  강천로  121(적금리  46)  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.7171754, 37.2551337]}
# {'place': '충남  서천군  장항읍  장항공단길  28번길  60', 'geometry.type': 'Point', 'geometry.coordinates': [126.7221482, 36.0087855]}
# {'place': '충북  청주시  흥덕구  화계동 29-15(LG화학  청주공장內)', 'geometry.type': 'Point', 'geometry.coordinates': [127.4408391, 36.6518765]}
# {'place': '부산시  강서구  국제물류도시  일반산업단지  1단계  제2공구  122-7Lot', 'geometry.type': 'Point', 'geometry.coordinates': [128.9805666, 35.2122157]}
# {'place': '광주시  서구  치평동  764-2번지  외  6필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.8288107, 35.1588903]}
# {'place': '강원  고성군  토성면  도원리 산1  외  6필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.4463953, 38.2699552]}
# {'place': '경북  영천시  화북면  정각리 산6-1,  산218-3,  포항시  죽장면  두마리  산84,  85,  98, 99  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9861839, 36.1583524]}
# {'place': '경북  포항시  남구  구룡포읍 석병리  산62번지  외  12필지', 'geometry.type': 'Point', 'geometry.coordinates': [129.5582378, 36.021601]}
# {'place': '전남  영광군  백수읍  하사리,약수리,  염산면  축동리,신성리,송암리  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3558487, 35.2625367]}
# {'place': '경북  포항시  남구  호미곶면 강사리  산199-1일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.5494377, 36.0330144]}
# {'place': '강원도  양양군  현남면  하월천리  산1-1번지,  상월천리 산1-1번지,  현북면  어성전리 산2번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.7038652, 37.9132061]}
# {'place': '충남  아산시  인주면  금성리 산  45', 'geometry.type': 'Point', 'geometry.coordinates': [126.8761849, 36.843786]}
# {'place': '전남  광양시  광양읍  세풍리 2200', 'geometry.type': 'Point', 'geometry.coordinates': [127.5877061, 34.9358814]}
# {'place': '충북  충주시  금가면  월상리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.8700852, 37.036753]}
# {'place': '경기도  평택시  포승읍  평택항로156번길  43', 'geometry.type': 'Point', 'geometry.coordinates': [126.8483984, 36.9755417]}
# {'place': '전남  광양시  황금동  산  191, 황금일반산업단지  內', 'geometry.type': 'Point', 'geometry.coordinates': [127.6155371, 34.9142315]}
# {'place': '경기도  평택시  포승읍  원정 리  1173-7', 'geometry.type': 'Point', 'geometry.coordinates': [126.8852807, 36.982824]}
# {'place': '전북  군산시  새만금  4호방조제  내측  일부', 'geometry.type': 'Point', 'geometry.coordinates': [126.482758, 35.820222]}
# {'place': '경북  군위군  고로면  석산리 산19번지  일원,  의성군  춘산면  신흥리  산70번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.8714507, 36.2009442]}
# {'place': '광주시  광산구  신창동  10-8', 'geometry.type': 'Point', 'geometry.coordinates': [126.8548358, 35.1943179]}
# {'place': '광주시  광산구  수완로  130(수완동  1149번지)', 'geometry.type': 'Point', 'geometry.coordinates': [126.8297814, 35.19685190000001]}
# {'place': '경남  함안군  군북면  장지리 1407', 'geometry.type': 'Point', 'geometry.coordinates': [128.3411532, 35.2858864]}
# {'place': '충북  음성군  대소면  대풍리 259-2번지  (CJ헬스케어  대소공장  내)', 'geometry.type': 'Point', 'geometry.coordinates': [127.4594926, 36.9835246]}
# {'place': '대구시  서구  이현동  산  117 번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.533509, 35.8787169]}
# {'place': '경북  문경시  신기공단2길 37  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.1734948, 36.6351007]}
# {'place': '경남  양산시  원동면  대리 산90-2번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9847647, 35.4517671]}
# {'place': '경남  양산시  동면  법기리 산1-1,  산1-3,  산14-1,  호계동  산69-1  번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.1100822, 35.3792888]}
# {'place': '경북  경주시  산내면  내일리 763-1,산421-3번지', 'geometry.type': 'Point', 'geometry.coordinates': [129.0772673, 35.74323589999999]}
# {'place': '경북  영양군  청기면  구매리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.0129844, 36.6627206]}
# {'place': '충북  음성군  맹동면  봉현리 22-6외  2필지', 'geometry.type': 'Point', 'geometry.coordinates': [127.5417032, 36.9548081]}
# {'place': '충북  단양군  매포읍  우덕리 360번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.3197171, 37.0247809]}
# {'place': '대구시  달성군  논공읍  본리리 29-55번지  및  1023번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.4601957, 35.7406053]}
# {'place': '경남  고성군  삼산면  병산리 532-1외  5필지', 'geometry.type': 'Point', 'geometry.coordinates': [128.2914564, 34.9505696]}
# {'place': '강원도  삼척시  도계읍  황조리 산159임  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.1032243, 37.2245719]}
# {'place': '강원도  삼척시  하장면  어리 산66번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9410834, 37.2879517]}
# {'place': '강원도  태백시  소도동  산78, 화전동  산47-61,  황지동    산176-1,14,16,  창죽동  산1-1,  혈동  산57', 'geometry.type': 'Point', 'geometry.coordinates': [128.9357453, 37.1951132]}
# {'place': '전북  고창군  상하면  용정리 1626번지외  27필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.45575, 35.4662909]}
# {'place': '강원도  평창군  봉평면  유포리 산200번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.3393122, 37.5229884]}
# {'place': '바이오 인천시 서구 오류동 1537번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.5949909, 37.58468269999999]}
# {'place': '경기도  화성시  남양읍  매바위로  570-10', 'geometry.type': 'Point', 'geometry.coordinates': [126.804204, 37.1553024]}
# {'place': '경기도  양주시  은현면  은남로 160', 'geometry.type': 'Point', 'geometry.coordinates': [127.0095212, 37.8931512]}
# {'place': '충남  서산시  대산읍  죽엽로 397일원(대죽리)', 'geometry.type': 'Point', 'geometry.coordinates': [126.4003556, 36.9830054]}
# {'place': '경북  포항시  북구  죽장면  상옥리  산20,  산15-1,  산15-2, 기북면  성법리  산1,  산2,  신광면  마북리   산2-1,  산12번지 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.214879, 36.2136872]}
# {'place': '강원도  평창군  용평면  노동리 산1-2', 'geometry.type': 'Point', 'geometry.coordinates': [128.4445405, 37.7071256]}
# {'place': '전남  고흥군  동강면  대강리 1219-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.301171, 34.7995899]}
# {'place': '경북  영덕군  남정면  중화리 산71-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3275572, 36.359231]}
# {'place': '경북  포항시  북구  죽장면  가사리  산2-1,석계리  산1-1', 'geometry.type': 'Point', 'geometry.coordinates': [129.1799187, 36.2198634]}
# {'place': '전남  여수시  중흥동  1724번지(여수국가산업단지內)', 'geometry.type': 'Point', 'geometry.coordinates': [127.6813647, 34.8252381]}
# {'place': '전남  여수시  화정면  백야리 산253번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.6341839, 34.616412]}
# {'place': '경북  영천시  자양면  용산리 산31번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.0279902, 36.1178214]}
# {'place': '강원도  평창군  용평면  도사리 산1번지,속사리  산270번지,  덕거리  산1번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.4405799, 37.64822170000001]}
# {'place': '강원도  삼척시  하장면  중봉리 산1,  도계읍  무건리  산58,  도계읍  황조리  산159,  도계읍 신리  산138,    삼척시  노곡면 주지리  산9,  노곡면  상마읍리 산104,  삼척시  원덕읍  이천리 산322,  삼척시  가곡면  오목리 산21번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.9386011, 37.4076278]}
# {'place': '광주시  서구  치평동  762-2번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.8288184, 35.1596556]}
# {'place': '충남  서산시  대산읍  독곶2로 103(한화토탈  대산공장  內)', 'geometry.type': 'Point', 'geometry.coordinates': [126.351237, 36.9916989]}
# {'place': '충북  청주시  청원군  북이면 신대석성로  253-4', 'geometry.type': 'Point', 'geometry.coordinates': [127.5192529, 36.7464716]}
# {'place': '경북  영천시  화북면  정각리 산150-1번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9842834, 36.1200955]}
# {'place': '강원  태백시  하사미동  산219-2,  산485-6,  산485-7,  산485-9', 'geometry.type': 'Point', 'geometry.coordinates': [128.9494799, 37.2919179]}
# {'place': '강원  평창군  용평면  노동리 산1-5,  산1-30도', 'geometry.type': 'Point', 'geometry.coordinates': [128.449901, 37.7075945]}
# {'place': '강원도  정선군  화암면  화암리 산58,  산111,  산101,  산115, 산116,  산145,  산146,  산150,   산152,  산169,  산170,  산171, 건천리  산265,  임계면  덕암리 산50-4', 'geometry.type': 'Point', 'geometry.coordinates': [128.8316717, 37.3543557]}
# {'place': '강원도  평창군  대화면  개수리 산340,  산337,  산618,  상암미리  산331,  방림면  방림리  산442,  계촌리    산1', 'geometry.type': 'Point', 'geometry.coordinates': [128.3676491, 37.44714159999999]}
# {'place': '경북  울진군  매화면  길곡리 산1번지', 'geometry.type': 'Point', 'geometry.coordinates': [129.3422373, 36.8228854]}
# {'place': '경북  포항시  북구  신광면  호리  87번지외  23필지', 'geometry.type': 'Point', 'geometry.coordinates': [129.2981568, 36.1206995]}
# {'place': '경기 시흥시 서울대학로 59-5(정왕동)', 'geometry.type': 'Point', 'geometry.coordinates': [126.7441252, 37.3630551]}
# {'place': '경기  포천시  신북면  신창길 36(신평리  206-3)  외', 'geometry.type': 'Point', 'geometry.coordinates': [127.2260675, 37.9540725]}
# {'place': '전북  전주시  덕진구  팔복동3가  478-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.0854561, 35.8544674]}
# {'place': '경기  용인시  남사면  천덕산로 428길  22', 'geometry.type': 'Point', 'geometry.coordinates': [127.1301197, 37.10562]}
# {'place': '경북  영덕군  달산면  매일리 산131번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.2649446, 36.381729]}
# {'place': '경북  영양군  석보면  포산리 일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.2097067, 36.5101474]}
# {'place': '강원  강릉시  강동면  임곡리 산21  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.9920227, 37.6883164]}
# {'place': '강원  정선군  고한읍  고한리 산  1-17번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.8571752, 37.1956294]}
# {'place': '전남  영광군  염산면  두우리 1128-3번지  등  및  공유수면 일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3036982, 35.2104724]}
# {'place': '강원도  평창군  횡계리  산 1-174', 'geometry.type': 'Point', 'geometry.coordinates': [128.7209909, 37.7031357]}
# {'place': '전남  여수시  화정면  조발리 산38-3번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.5596332, 34.63510910000001]}
# ...
# {'place': '경북  봉화군  춘양면  우구치리  산1-70,  산1-19', 'geometry.type': 'Point', 'geometry.coordinates': [128.7810628, 37.0519353]}
# {'place': '강원도  삼척시  근덕면  매원리  산75,  산82,  산184, 산288', 'geometry.type': 'Point', 'geometry.coordinates': [129.2894317, 37.2946775]}
# {'place': '울산  동측  60km  앞  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '경기  화성시  향남읍  방축리  467', 'geometry.type': 'Point', 'geometry.coordinates': [126.9212463, 37.1151401]}
# {'place': '경기  용인시  처인구  남동 524-5,  530-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.2000933, 37.22095890000001]}
# {'place': '경기  이천시  설성면  자석리  135', 'geometry.type': 'Point', 'geometry.coordinates': [127.5692598, 37.1705738]}
# {'place': '강원  영월군  북면  마차리 산1-1', 'geometry.type': 'Point', 'geometry.coordinates': [128.4764527, 37.2729055]}
# {'place': '강원도  고성군  현내면  마달리  산3번지,  산5번지,  철통리  산63번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4036683, 38.5159685]}
# {'place': '강원도  고성군  간성읍  교동리  산2,  산3', 'geometry.type': 'Point', 'geometry.coordinates': [128.4511443, 38.3855469]}
# {'place': '경남  하동군  금남면  대송리  대송산업단지  A9-2', 'geometry.type': 'Point', 'geometry.coordinates': [127.8520885, 34.9764065]}
# {'place': '전북  익산시  낭산면  용기리  1946', 'geometry.type': 'Point', 'geometry.coordinates': [126.9879187, 36.0547774]}
# {'place': '울산  남구  여천동  321', 'geometry.type': 'Point', 'geometry.coordinates': [129.3583347, 35.5192323]}
# {'place': '경북  포항시  북구  청하면 명안리  산24번지  외7필지', 'geometry.type': 'Point', 'geometry.coordinates': [129.300242, 36.1810242]}
# {'place': '충북  음성군  음성읍  한벌리  산52,  산54-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.6998164, 36.9490337]}
# {'place': '울산광역시  울주군  삼남읍 상천리  427-130,  427-474, 427-527,  427-174, 427-251,    427-478', 'geometry.type': 'Point', 'geometry.coordinates': [129.106335, 35.5276079]}
# {'place': '경북  영덕군  영덕읍  매정리  1161번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.4062801, 36.454368]}
# {'place': '경남  거제시  연초면  오비리  산6-2번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.6148396, 34.9174717]}
# {'place': '강원도  태백시  동점동  동점산업단지  블록  3-6(동점산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.0464035, 37.0845505]}
# {'place': '충남  서산시  대산읍  대죽리  640-6  현대오일뱅크  대산공장', 'geometry.type': 'Point', 'geometry.coordinates': [126.4019857, 37.000816]}
# {'place': '인천시  중구  용유동', 'geometry.type': 'Point', 'geometry.coordinates': [126.4024178, 37.44384489999999]}
# {'place': '전남  진도군  조도면 가사도리  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [126.0486598, 34.4815801]}
# {'place': '울산  울주군  청량읍 상개로 63-76', 'geometry.type': 'Point', 'geometry.coordinates': [129.3177583, 35.4891407]}
# {'place': '경북  안동시  상아동 산3-3', 'geometry.type': 'Point', 'geometry.coordinates': [128.7449683, 36.5870676]}
# {'place': '경북  의성군  옥산면 금봉리  산13,  산20, 산22', 'geometry.type': 'Point', 'geometry.coordinates': [128.869459, 36.3381653]}
# {'place': '제주도  서귀포시  표선면 가시리 3604 등 9개필지(3649, 3646, 3645,  3644,  3652-1,  3652-2, 3652-3, 3668-1)', 'geometry.type': 'Point', 'geometry.coordinates': [126.7063341, 33.3988071]}
# {'place': '전남  여수시  율촌면 신풍리 5-5번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.6358983, 34.844466]}
# {'place': '전남  여수시  율촌면 신풍리 5-6번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.6360268, 34.8440815]}
# {'place': '전남  영암군  삼호읍 난전리 1689-3', 'geometry.type': 'Point', 'geometry.coordinates': [126.4216201, 34.7719718]}
# {'place': '대구광역시 달서구 달서대로210(대천동774) 일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.4982708, 35.8216855]}
# {'place': '부산광역시 강서구 명지동 3043일원(부산 에코델타시티  집단에너지부지 내)', 'geometry.type': 'Point', 'geometry.coordinates': [128.9077103, 35.1256951]}
# {'place': '전남  여수시  남면  금오도 인근  해상', 'geometry.type': 'Point', 'geometry.coordinates': [127.7359226, 34.5308016]}
# {'place': '울산시  울산항  동측  58km 앞  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3734649, 35.5192983]}
# {'place': '충남  태안군  고남면  장곡리  783-1외  6필지,  안면읍 중장리  2300-1외  13필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3660499, 36.4427433]}
# {'place': '충남  서산시  대산읍  독곶 2로  50', 'geometry.type': 'Point', 'geometry.coordinates': [126.362671, 36.9959976]}
# {'place': '경남  고성군  하이면  덕호리  889-6', 'geometry.type': 'Point', 'geometry.coordinates': [128.1126122, 34.9131431]}
# {'place': '전북  전주시  완산구  삼산길  51-70', 'geometry.type': 'Point', 'geometry.coordinates': [127.0732172, 35.7987616]}
# {'place': '경기  화성시  송산면  사강리  256-2,  256-11', 'geometry.type': 'Point', 'geometry.coordinates': [126.7205918, 37.2189449]}
# {'place': '충남  아산시  둔포면  관대리 53-3,4,5,9,10,12,14,122-9', 'geometry.type': 'Point', 'geometry.coordinates': [127.0350161, 36.9085714]}
# {'place': '충남  보령시  주교면  관창리  1224-1  관창일반산업단지  내', 'geometry.type': 'Point', 'geometry.coordinates': [126.5742237, 36.3770996]}
# {'place': '광주시  광산구  고룡동  산56-16', 'geometry.type': 'Point', 'geometry.coordinates': [126.7804517, 35.2040844]}
# {'place': '전남 영암군 삼호읍 난전리  1689-3', 'geometry.type': 'Point', 'geometry.coordinates': [126.4216201, 34.7719718]}
# {'place': '강원도  고성군  간성읍  금수리  산9-5,  9-6', 'geometry.type': 'Point', 'geometry.coordinates': [128.4752538, 38.3705023]}
# {'place': '경북  칠곡군  약목면  복성리  750', 'geometry.type': 'Point', 'geometry.coordinates': [128.3584429, 36.0342674]}
# {'place': '울산시 북구 효암로 84-13', 'geometry.type': 'Point', 'geometry.coordinates': [129.3666775, 35.5547591]}
# Not able to process: 전남  고흥군  도양읍  시산도  해상    일원
# {'place': '전남  여수시  삼산면  손죽리  역만도  일원    해상', 'geometry.type': 'Point', 'geometry.coordinates': [127.3543852, 34.1732689]}
# {'place': '전남  여수시  삼산면  초도리  일원    공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [127.2386939, 34.2267913]}
# {'place': '울산시  동측  60km  앞  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '울산시동측60km앞공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '울산동측63km앞공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '당진시 석문면 교로리  2304  외  117필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.5047819, 37.0144574]}
# {'place': '강원도  태백시  동점동  동 점산업단지  블록  3-3', 'geometry.type': 'Point', 'geometry.coordinates': [129.0509505, 37.0942103]}
# {'place': '강원도 태백시 동점동 동점산업단지 블록 3-4(태백시 동점산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.0464035, 37.0845505]}
# {'place': '강원도  태백시  동점동  동점산업단지  블록  3-6(동점산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.0464035, 37.0845505]}
# {'place': '전북  군산시 새만금산업단지  5공구 산-13일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.5870503, 35.9474649]}
# {'place': '경기평택시고덕면해창리1278-1', 'geometry.type': 'Point', 'geometry.coordinates': [127.0193638, 37.0274047]}
# {'place': '강원도정선군사북읍사북리산155-38일원(하이원리조트부지내)', 'geometry.type': 'Point', 'geometry.coordinates': [128.8225339, 37.212986]}
# {'place': '울산남구여천동198,209-37(울산미포국가산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.3584669, 35.5154368]}
# {'place': '충남공주시이인면만수리산37-7(남공주일반산단내)', 'geometry.type': 'Point', 'geometry.coordinates': [127.096778, 36.332361]}
# {'place': '강원도  영월군  김삿갓면 옥동리  산10-1,  대야리  산1,  산7,  와석리  산1-3', 'geometry.type': 'Point', 'geometry.coordinates': [128.5822569, 37.1027788]}
# {'place': '경북  군위군  삼국유사면 화북리  1269-24,  1269-28', 'geometry.type': 'Point', 'geometry.coordinates': [128.7674529, 36.1004992]}
# {'place': '경북  군위군  삼국유사면 화수리  산45-1,  산44', 'geometry.type': 'Point', 'geometry.coordinates': [128.7584813, 36.1020786]}
# {'place': '경북  군위군  삼국유사면 화수리  산45-1,  산44', 'geometry.type': 'Point', 'geometry.coordinates': [128.7584813, 36.1020786]}
# {'place': '충남  태안군  원북면  방갈리  796번지  외  51필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.2225956, 36.8782698]}
# {'place': '경북  예천군  지보면  매창리  939번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [128.3522645, 36.541596]}
# {'place': '전남  여수시  산단중앙로 275(여수국가산단내)', 'geometry.type': 'Point', 'geometry.coordinates': [127.6648707, 34.8284858]}
# {'place': '울산광역시  동측  87km  배타적  경제수역내', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '경북  영덕군  영덕읍  매정리  산54,  축산면  고곡리 산139-3번지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.4169927, 36.4649849]}
# {'place': '울산  동측  60km  앞  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '울산시  온산  해안  동측 80km  공유수면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3146114, 35.4346298]}
# {'place': '울산시  온산  해안  동측 85km  공유수면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3146114, 35.4346298]}
# {'place': '울산시  동측  90km  배타적 경제수역내', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '울산  동측  70km  앞  공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '울산동측70km앞공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.3113596, 35.5383773]}
# {'place': '충청북도  영동군  상촌면 고자리  일원,  양강면  산막리  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.8396796, 36.1002673]}
# {'place': '강원도  홍천군  화촌면  풍천리  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.896583, 37.83262]}
# {'place': '경기도  포천시  이동면  도평리  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.4032977, 38.0757063]}
# {'place': '경북  포항시  북구  흥해읍 용한리  산155-4,  죽천리   14-1,  14-2번지(영일만4일반산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.4146327, 36.099562]}
# {'place': '경북  포항시  남구  동해면 상정리  1001-2(포항블루밸리  국가산단내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.4875634, 35.9822953]}
# {'place': '경북  의성군  의성읍  철파리  531,  532-2,  533-2, 530-1,  530-2  번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.6685978, 36.3619049]}
# {'place': '경북  의성군  의성읍  철파리  531,  532-2,  533-2, 530-1,  530-2  번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.6685978, 36.3619049]}
# {'place': '강원도태백시동점동동점산업단지블록3-5(태백시동점산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.0464035, 37.0845505]}
# {'place': '강원도  태백시  동점동  동점산업단지  블록  3-5(태백시  동점산업단지내)', 'geometry.type': 'Point', 'geometry.coordinates': [129.0464035, 37.0845505]}
# {'place': '경북 경주시 강동면 유금 리  산44-5', 'geometry.type': 'Point', 'geometry.coordinates': [129.2834205, 36.006545]}
# {'place': '전남  고흥군  봉래면  신금리  나로도  서쪽    공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [127.4666951, 34.4605364]}
# {'place': '전남 고흥군 봉래면 신금 풍력', 'geometry.type': 'Point', 'geometry.coordinates': [127.464157, 34.468904]}
# {'place': '충남  태안군  태안읍  어은리  864-1  외  19필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3156682, 36.8126074]}
# {'place': '경북  구미시  산동읍  도중리  구미하이테크밸리  4구역  19B,  102L', 'geometry.type': 'Point', 'geometry.coordinates': [128.4341684, 36.1928494]}
# {'place': '경북  안동시  상아동  산3-1', 'geometry.type': 'Point', 'geometry.coordinates': [128.7449683, 36.5870676]}
# {'place': '경북  안동시  상아동  산3-4', 'geometry.type': 'Point', 'geometry.coordinates': [128.7449683, 36.5870676]}
# {'place': '전남  여수시  율촌면  신풍리  2-8번지', 'geometry.type': 'Point', 'geometry.coordinates': [127.6356441, 34.8450665]}
# {'place': '울산시  온산  해안  동측 90km  공유수면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3146114, 35.4346298]}
# {'place': '경북  영덕군  축산면  고곡리  산144,  산94,  산78,  산57,  경정리  산99,  산150, 영덕읍  석리    산92-1', 'geometry.type': 'Point', 'geometry.coordinates': [129.4074059, 36.4667267]}
# {'place': '경남  하동군  금남면  대송리・진정리  일원(대송산업단지  내)', 'geometry.type': 'Point', 'geometry.coordinates': [127.8520885, 34.9764065]}
# {'place': '울산시  남구  성암동  산86-1일원', 'geometry.type': 'Point', 'geometry.coordinates': [129.3518312, 35.48962]}
# {'place': '강원도  평창군  진부면  상월오개리  산97-1,용평면 속사리    산188,  이목정리 산30', 'geometry.type': 'Point', 'geometry.coordinates': [128.514401, 37.6364589]}
# {'place': '경북  포항시  북구  흥해읍 용한리(영일만3일반산업단지)', 'geometry.type': 'Point', 'geometry.coordinates': [129.4321372, 36.1106446]}
# {'place': '전남해남군문내면무고리인 근공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [126.3083924, 34.627737]}
# {'place': '울산시북구정자항앞공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [129.4425386, 35.6146553]}
# {'place': '전남여수시거문도서측공유수면', 'geometry.type': 'Point', 'geometry.coordinates': [127.3183346, 34.0485456]}
# {'place': '경북  경주시  외동읍  문산 연 료 전 지 리  산  82-14', 'geometry.type': 'Point', 'geometry.coordinates': [129.319327, 35.6793888]}
# {'place': '경남  함안군  칠북면  덕남길  69(화천리  16)', 'geometry.type': 'Point', 'geometry.coordinates': [128.5160011, 35.3552602]}
# {'place': '전남  여수시  소라면  대포리  1346-11  등  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.6371449, 34.8212719]}
# {'place': '경기도  남양주시  화도읍 답내리  722,  723,  13-15', 'geometry.type': 'Point', 'geometry.coordinates': [127.3373435, 37.6699041]}
# {'place': '전남  영광군  홍농읍  칠곡리  산226  앞  해상   일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3984159, 35.3823418]}
# {'place': '강원도  평창군  봉평면  진조리  산80-68', 'geometry.type': 'Point', 'geometry.coordinates': [128.2856326, 37.5834959]}
# {'place': '전남  고흥군  포두면  송산리  1655-1  등  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.3655625, 34.6062257]}
# {'place': '부산시  강서구  에코델타시티  집단에너지  부지내(명 지동  3043일원)', 'geometry.type': 'Point', 'geometry.coordinates': [128.9077103, 35.1256951]}
# {'place': '강원도  양양군  손양면  상왕도리  산42  번지', 'geometry.type': 'Point', 'geometry.coordinates': [128.6322315, 38.0389521]}
# {'place': '경기도  안양시  만안구  안양동  206-12  및  206-7', 'geometry.type': 'Point', 'geometry.coordinates': [126.9392954, 37.3838743]}
# {'place': '경기도  남양주  왕숙  공공주택지구', 'geometry.type': 'Point', 'geometry.coordinates': [127.1618493, 37.6880177]}
# {'place': '경기도  남양주  왕숙  공공주택지구', 'geometry.type': 'Point', 'geometry.coordinates': [127.1618493, 37.6880177]}
# {'place': '전남  완도군  생일면  봉선리  산276  남쪽   해상', 'geometry.type': 'Point', 'geometry.coordinates': [126.9854204, 34.3149688]}
# {'place': '전남  강진군  신전면  사초리  697번지  등  63필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.722606, 34.4717805]}
# {'place': '전남  영광군  백수읍  하사리  1887-1번지', 'geometry.type': 'Point', 'geometry.coordinates': [126.3269556, 35.2574923]}
# {'place': '전남  신안군  안좌면  대우리  1069번지  등  30필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.0981003, 34.73385]}
# {'place': '전남  신안군  안좌면  내호리  693번지  등  14필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.0844936, 34.7392268]}
# {'place': '전남  신안군  안좌면  대우리  981번지  등  14필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.096601, 34.73995379999999]}
# {'place': '전남  고흥군  포두면  남촌리  1035-1  외  227필지', 'geometry.type': 'Point', 'geometry.coordinates': [127.3580933, 34.594089]}
# {'place': '전남  전남  영광군  백수읍 하사리 3038외  공유수면   일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.3558487, 35.2625367]}
# {'place': '전남  진도군  조도면  관매도  및  독거도  인근  공유수면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.0560872, 34.2400303]}
# {'place': '전남  고흥군  풍양면  안동리  769-1번지  외  37필지', 'geometry.type': 'Point', 'geometry.coordinates': [127.2069854, 34.5561314]}
# {'place': '전남  완도군  약산면  관산리,  우두리  등  84필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.8896786, 34.3793858]}
# {'place': '전남  신안군  안좌면  탄동리  447,  448', 'geometry.type': 'Point', 'geometry.coordinates': [126.1642808, 34.7466822]}
# {'place': '전남  신안군  안좌면  탄동리  449-1  외  6필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.1630236, 34.75]}
# {'place': '전남  진도군  지산면  거제 리  보전호  공유수면  일원', 'geometry.type': 'Point', 'geometry.coordinates': [126.1681544, 34.4801704]}
# {'place': '전남  고흥군  도덕면  오마리  815-1번지  외  34필지', 'geometry.type': 'Point', 'geometry.coordinates': [127.1956234, 34.5390034]}
# {'place': '전남  고흥군  도덕면  오마리  1018-7  등  23필지  일원', 'geometry.type': 'Point', 'geometry.coordinates': [127.1956234, 34.5390034]}
# {'place': '전남  진도군  조도면  외병도리 해상  일원', 'geometry.type': 'Point', 'geometry.coordinates': [125.9405277, 34.3697474]}
# {'place': '근 )전남  여수시  거문도  인근 해역', 'geometry.type': 'Point', 'geometry.coordinates': [127.3183346, 34.0485456]}
# {'place': '전남  목포시  대양동  703번지  외  21필지', 'geometry.type': 'Point', 'geometry.coordinates': [126.4074178, 34.8364123]}

# %%
not_processed
# Out:
# ['인천시 서구 원창동인천 화력발전소',
#  '전남  신안군  하의면  후광3리(장병도)  산50번지  일원',
#  '경기도  화성시  남양읍  북양리  산51번지',
#  '전 남 신 안 군 지 도 읍 어 의 리',
#  '전 북 군 산 시 옥 구 읍 어 은 리 태양광 1550,1550-1,1550-2,1551,1552,1566,1567,1568,1573-6,1573-119,1573-16,1573-136,                                 1573-26,      1573-35,1575',
#  '경북  구미시  산동면  국가5산업단지(하이테크밸리)  내',
#  '전남신안군지도읍어의리어의도앞해상',
#  '리  156-1',
#  '경기도  화성시  남양읍  북양리  산51번지,  53번지',
#  '리  240번지  외  85필지',
#  '산업단지  B-05',
#  '전남  고흥군  도양읍  시산도  해상    일원']

# %%
# df.loc[df.address=="리  773-20번지  일원", 'address'] = "충북 진천군 광혜원면 광혜원리 773-20번지 일원"
df.loc[df.address=="리  156-1", 'address'] = "전남 신안군 비금면 도고리 156-1"
# df.loc[df.address=="리  산93,  96,  100-1", 'address'] = "경북 안동시 임하면 신덕리  산93,  96,  100-1"
df.loc[df.company=="신덕송계태양 경북 안동시 임하면 신덕 광발전", 'company'] = "신덕송계태양광발전"
df.loc[df.address=="리 240번지 외 85필지", 'address'] = "전남 신안군 안좌면 대우리 240번지 외 85필지"
# df.loc[df.company=="그린테크시티 전남 신안군 안좌면 대우", 'company'] = "그린테크시티"
df.loc[df.address=="산업단지 B-05", 'address'] = "경남 하동군 금남면 대송산업단지 B-05"
df.loc[df.company=="한국수소발전 경남 하동군 금남면 대송", 'company'] = "한국수소발전"
# df.loc[df.address=="리  1689-3", 'address'] = "전남 영암군 삼호읍 난전리  1689-3"
df.loc[df.company=="영암그린파워 전남 영암군 삼호읍 난전", 'company'] = "영암그린파워"
# df.loc[df.address=="490", 'address'] = "경기도 연천군 전곡읍 양연로 490"

# %%
df.to_csv("cleaned_df_updated_address.csv", index=False)

# %%
len(not_processed)
# Out:
# 12

# %%
# Manually add coordinates for addresses with errors

# Address 1: 인천시 서구 원창동인천 화력발전소
mygeometry = {'place': "인천시 서구 원창동인천 화력발전소", 'geometry.type': 'Point','geometry.coordinates': [126.60847324245631, 37.53605097894146]}
geometry_df.append(mygeometry)

# Address 2: 충북 진천군 광혜원면 광혜원리 773-20번지 일원
# mygeometry = {'place': "충북 진천군 광혜원면 광혜원리 773-20번지 일원", 'geometry.type': 'Point','geometry.coordinates': [127.43554686942524, 36.980172381325666]}
# geometry_df.append(mygeometry)

# Address 3: 전남  신안군  하의면  후광3리(장병도)  산50번지  일원
mygeometry = {'place': "전남  신안군  하의면  후광3리(장병도)  산50번지  일원", 'geometry.type': 'Point','geometry.coordinates': [126.04729041675004, 34.656425822471995]}
geometry_df.append(mygeometry)

# Address 4: 경기도  화성시  남양읍  북양리  산51번지
mygeometry = {'place': "경기도  화성시  남양읍  북양리  산51번지", 'geometry.type': 'Point','geometry.coordinates': [126.04729041675004, 34.656425822471995]}
geometry_df.append(mygeometry)

# Address 5: 전 남 신 안 군 지 도 읍 어 의 리
mygeometry = {'place': "전 남 신 안 군 지 도 읍 어 의 리", 'geometry.type': 'Point','geometry.coordinates': [126.1912233612765, 35.1375765124639]}
geometry_df.append(mygeometry)

# Address 6: 전 북 군 산 시 옥 구 읍 어 은 리 태양광 1550,1550-1,1550-2,1551,1552,1566,1567,1568,1573-6,1573-119,1573-16,1573-136,                                 1573-26,      1573-35,1575
mygeometry = {'place': "전 북 군 산 시 옥 구 읍 어 은 리 태양광 1550,1550-1,1550-2,1551,1552,1566,1567,1568,1573-6,1573-119,1573-16,1573-136,                                 1573-26,      1573-35,1575", 'geometry.type': 'Point','geometry.coordinates': [126.66879081327278, 35.89909021664055]}
geometry_df.append(mygeometry)

# Address 7: 경북  구미시  산동면  국가5산업단지(하이테크밸리)  내
mygeometry = {'place': "경북  구미시  산동면  국가5산업단지(하이테크밸리)  내", 'geometry.type': 'Point','geometry.coordinates': [128.4424582825869, 36.151251976367746]}
geometry_df.append(mygeometry)

# Address 8: 전남신안군지도읍어의리어의도앞해상
mygeometry = {'place': "전남신안군지도읍어의리어의도앞해상", 'geometry.type': 'Point','geometry.coordinates': [126.18697497635216, 35.13059038600237]}
geometry_df.append(mygeometry)

# Address 9: 전남 신안군 비금면 도고리 156-1
mygeometry = {'place': "전남 신안군 비금면 도고리 156-1", 'geometry.type': 'Point','geometry.coordinates': [125.97338372890114, 34.76161514669258]}
geometry_df.append(mygeometry)

# Address 10: 경북 안동시 임하면 신덕리  산93,  96,  100-1
# mygeometry = {'place': "경북 안동시 임하면 신덕리  산93,  96,  100-1", 'geometry.type': 'Point','geometry.coordinates': [128.83157659825073, 36.51575239781046]}
# geometry_df.append(mygeometry)

# Address 11: 경기도  화성시  남양읍  북양리  산51번지,  53번지
mygeometry = {'place': "경기도  화성시  남양읍  북양리  산51번지,  53번지", 'geometry.type': 'Point','geometry.coordinates': [126.8303034588272, 37.21984130662507]}
geometry_df.append(mygeometry)

# Address 12: 전남 신안군 안좌면 대우리 240번지 외 85필지
mygeometry = {'place': "전남 신안군 안좌면 대우리 240번지 외 85필지", 'geometry.type': 'Point','geometry.coordinates': [126.10154632704639, 34.7394748942027]}
geometry_df.append(mygeometry)

# Address 13: 경남 하동군 금남면 대송산업단지 B-05
mygeometry = {'place': "경남 하동군 금남면 대송산업단지 B-05", 'geometry.type': 'Point','geometry.coordinates': [127.76194722705362, 35.06103028430659]}
geometry_df.append(mygeometry)

# Address 14: 전남 영암군 삼호읍 난전리  1689-3
# mygeometry = {'place': "전남 영암군 삼호읍 난전리  1689-3", 'geometry.type': 'Point','geometry.coordinates': [126.42159864053826, 34.77214803961485]}
# geometry_df.append(mygeometry)

# Address 15: 전남  고흥군  도양읍  시산도  해상    일원
mygeometry = {'place': "전남  고흥군  도양읍  시산도  해상    일원", 'geometry.type': 'Point','geometry.coordinates': [127.26026361277185, 34.38937734730352]}
geometry_df.append(mygeometry)

# Address 16: 경기도 연천군 전곡읍 양연로 490
# mygeometry = {'place': "경기도 연천군 전곡읍 양연로 490", 'geometry.type': 'Point','geometry.coordinates': [127.00478125595711, 37.95086092180179]}
# geometry_df.append(mygeometry)

# %%
for place in geometry_df:
    if place == {}:
        geometry_df.remove(place)

# %%
# for place in geometry_df:
#     if place['place'] == "490":
#         geometry_df.remove(place)

# %%
len(geometry_df)
# Out:
# 1089

# %%
import json
with open('12-10-22-7pm.json', 'w') as fp:
    json.dump(geometry_df, fp)

# %%
with open('/Users/minjukim/Documents/GitHub/korec_energy_permitting/1089_full.json') as json_data:
    geometry_data = json.load(json_data)

geometry_data
# Out:
# [{'place': '강원도 평창군 도암면횡계리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7113813, 37.6758316]},
#  {'place': '전남 여수시 월내동 350',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7322701, 34.8465274]},
#  {'place': '인천시 부평구 갈산1동94',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7274146, 37.515326]},
#  {'place': '인천시 서구 백석동 58',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6616801, 37.57627919999999]},
#  {'place': '충남 보령시 오천면오포리 산 212',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5191246, 36.4007416]},
#  {'place': '충남 태안군 원북면방갈리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2247896, 36.8948887]},
#  {'place': '충남 당진군 송악면부곡1리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0089277, 36.7317626]},
#  {'place': '충남 당진군 석문면교로리 산 974',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5096353, 37.0326652]},
#  {'place': '경남 양산시 원동면대리 산 93-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9823266, 35.4245391]},
#  {'place': '대전시 유성구 금고동산21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3561329, 36.362216]},
#  {'place': '전남 순천시 해룡면율촌 제1산단',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.579634, 34.883407]},
#  {'place': '경남 하동군 금성면가덕리 310',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8207435, 34.9511205]},
#  {'place': '인천시 서구 백석동 58',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6616801, 37.57627919999999]},
#  {'place': '경북 영덕군 영덕읍창포리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4213426, 36.4201595]},
#  {'place': '전남 광양시 금호동광양제철소 스래그처리장',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7361051, 34.9328653]},
#  {'place': '제주시 삼양1동 900',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5954907, 33.5345378]},
#  {'place': '제주도 남제주군 안덕면화순리 610',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3403647, 33.2367154]},
#  {'place': '경남 양산시 원동면대리 산 93-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9823266, 35.4245391]},
#  {'place': '인천시 옹진군 영흥면외리 산 168',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4544618, 37.2479998]},
#  {'place': '대전시 대덕구 연축동산 6-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.4155717, 36.3467189]},
#  {'place': '경남 양산시 원동면대리 산 93',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9713693, 35.4407412]},
#  {'place': '부산시 기장군 장안읍효암리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2991326, 35.3323776]},
#  {'place': '전주시 완산구 상림동산 180-6',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.074539, 35.815511]},
#  {'place': '경남 통영시 광도면안정리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4060882, 34.9449106]},
#  {'place': '경북 예천군 하리면송월리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4245023, 36.7573156]},
#  {'place': '강원도 양양군 서면영덕리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.5292364, 38.0151898]},
#  {'place': '경북 청송군 파천면신흥리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.038129, 36.3946384]},
#  {'place': '충남 당진군 석문면교로리 산 974',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5096353, 37.0326652]},
#  {'place': '경북 경주시 양북면봉길리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4708845, 35.731638]},
#  {'place': '인천시 서구 원창동 336',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6075105, 37.5114549]},
#  {'place': '전북 군산시 비옹도동군장 국가산단',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5317163, 35.9596094]},
#  {'place': '충남 보령시 오천면보령화력내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5224226, 36.4383534]},
#  {'place': '인천시 서구 원창동244-17외',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6129443, 37.5067488]},
#  {'place': '경기도 이천시 호법면안평3리 산 98',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.412489, 37.242498]},
#  {'place': '경북 영양군 석보면요원리 삼의리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.212156, 36.563666]},
#  {'place': '전북 군산시 경암동590-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7287, 35.9821405]},
#  {'place': '충남 서산시 대산읍독곶리 634',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.37117, 36.9981699]},
#  {'place': '강원도 횡성군 둔내면태기리산 1-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.2471963, 37.5931718]},
#  {'place': '전북 고창군 흥덕면치룡리 100',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7113226, 35.5380886]},
#  {'place': '경남 양산시 원동면대리 산 93',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9713693, 35.4407412]},
#  {'place': '경남 밀양시 산내면삼양리 산 1-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0063704, 35.5893496]},
#  {'place': '충남 보령 청소면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5895468, 36.4454104]},
#  {'place': '강원도 춘천 송암동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6875981, 37.854583]},
#  {'place': '경기 고양 백석동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7888593, 37.6403518]},
#  {'place': '강원 삼척 하장면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9430045, 37.3495284]},
#  {'place': '경북 김천 어모면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1185266, 36.1804936]},
#  {'place': '경북 김천 어모면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1185266, 36.1804936]},
#  {'place': '전남 영광 백수읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4208079, 35.28324110000001]},
#  {'place': '인천 연수 동천동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6783088, 37.4094099]},
#  {'place': '경기 평택 오성면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9802778, 37.0077109]},
#  {'place': '전남 광양 금호동 640',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7355026, 34.91476]},
#  {'place': '경북 김천 봉산면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.0602867, 36.1414843]},
#  {'place': '전북 익산시 부송동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9953047, 35.9715334]},
#  {'place': '충남 당진 송악면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.69346, 36.9006388]},
#  {'place': '경기 가평 설악면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.4947001, 37.6761522]},
#  {'place': '경기 화성 봉담읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9502589, 37.220154]},
#  {'place': '경북 울진 북면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3730649, 37.1048627]},
#  {'place': '경기 부천 삼정동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7678241, 37.5242118]},
#  {'place': '충남 당진 석문면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5908916, 36.9819022]},
#  {'place': '충남 서산 대산읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4343234, 36.9395813]},
#  {'place': '인천 옹진 영흥',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4627227, 37.2636183]},
#  {'place': '경기 여주 능서면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5735231, 37.3001551]},
#  {'place': '대구 달서 대천동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.495774, 35.824871]},
#  {'place': '강원 원주 지정면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8401841, 37.362118]},
#  {'place': '경기 포천 창수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1891285, 37.9915306]},
#  {'place': '부산 강서 생곡동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8800328, 35.1325238]},
#  {'place': '강원 태백 창죽동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9587665, 37.236246]},
#  {'place': '경기 포천 창수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1891285, 37.9915306]},
#  {'place': '강원 삼척 윈덕읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3432037, 37.2325164]},
#  {'place': '충남 태안 원북면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2571599, 36.8234084]},
#  {'place': '부산 강서구',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9805666, 35.2122157]},
#  {'place': '강원 동해시 구호동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1437223, 37.480706]},
#  {'place': '경기 동두천시 광암동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1009159, 37.9067614]},
#  {'place': '경남 어곡동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0075416, 35.3972531]},
#  {'place': '경북 포항시 남구',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3592306, 36.0086283]},
#  {'place': '강원도 동해시 삼화동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.068103, 37.4908884]},
#  {'place': '경북 영주시 평은면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.6758264, 36.7430181]},
#  {'place': '경북 경주시 양북면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4430326, 35.7910787]},
#  {'place': '충남 보령시 주교면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5692554, 36.3908376]},
#  {'place': '전남 신안군 팔금면 원산리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.1143338, 34.786947]},
#  {'place': '전남 신안군 팔금면 진고리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.157117, 34.7730806]},
#  {'place': '전남 영암군 금정면 연소리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.780318, 34.8214605]},
#  {'place': '경기 파주시 파주읍봉암리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7954201, 37.8214984]},
#  {'place': '서울 마포구 당인동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9194445, 37.54273939999999]},
#  {'place': '경북 안동시 풍산읍 괴정리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.536271, 36.5985998]},
#  {'place': '경북 경주시 감포읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.5016796, 35.8074391]},
#  {'place': '경북 경주시 양남면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4604091, 35.6778061]},
#  {'place': '충남 태안군 원북면발전로 447-40',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2312041, 36.8979989]},
#  {'place': '충남 당진군 송악면부곡리 564',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7813551, 36.9571468]},
#  {'place': '경북 경주시 천군동1516번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2696275, 35.8193388]},
#  {'place': '경북 영양군 영양읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1141518, 36.6670434]},
#  {'place': '부산 강서구 신호동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8807923, 35.09025]},
#  {'place': '부산 강서구 신호동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8807923, 35.09025]},
#  {'place': '경남 양산시 원동면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9187874, 35.3646853]},
#  {'place': '경기도 화성시 향남읍',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9199753, 37.1321066]},
#  {'place': '울산 남구 남화동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3767054, 35.4761122]},
#  {'place': '경기도 평택시 포승면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8852807, 36.982824]},
#  {'place': '전남 해남군 황산면원호리 435-1외 5필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4869616, 34.5680133]},
#  {'place': '전남 영암군 삼호읍삼포리 1895-8',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3902632, 34.7398737]},
#  {'place': '경기도 안산시 초지동MTV5공구 BL 103-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8085765, 37.3246446]},
#  {'place': '서울시 강남구 논현로 508서울시 영등포구여의도동35-6',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0372776, 37.5018592]},
#  {'place': '경기도 오산시 누읍동332',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0558201, 37.140655]},
#  {'place': '충남 서산시 대산읍독곶리 411-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3540793, 37.0044]},
#  {'place': '강원도 태백시 창죽동산63번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9583529, 37.2462236]},
#  {'place': '충남 당진시 석문면교로3리 1026외',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5908916, 36.9819022]},
#  {'place': '대전시 대덕구 신일서로68번길 71',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.403595, 36.4345023]},
#  {'place': '경기도 평택시 죽백동334-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1211621, 37.0100041]},
#  {'place': '전남 해남군 황산면호동리 909-21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4328595, 34.5542521]},
#  {'place': '전남 해남군 황산면한자리726,752-1,747및호동리968-6',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.437281, 34.5510899]},
#  {'place': '경기도 하남시 풍산동일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1864773, 37.5494849]},
#  {'place': '전북 군산시 소룡동53-8',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6401594, 35.977753]},
#  {'place': '경기도 시흥시 정왕동시화공단 2바 101',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7271088, 37.34860159999999]},
#  {'place': '강원도 원주시 지정면신평리 420-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8898361, 37.3724899]},
#  {'place': '충북 청원군 옥산면국사리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3744217, 36.687463]},
#  {'place': '경기도 화성시 석우동39,동탄면 방교리 634',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0927885, 37.1764742]},
#  {'place': '경남 진주시 남강로1317길 24',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.0974023, 35.1784006]},
#  {'place': '경기도 안산시 초지동672',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.794652, 37.2954745]},
#  {'place': '경기도 하남시 학암동일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1616155, 37.4776989]},
#  {'place': '경기도 부천시 오정구삼정동 363-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7637195, 37.5220107]},
#  {'place': '경기도 이천시 대월면초지리 57',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5017476, 37.2361558]},
#  {'place': '전남 여수시 월화동144-16 화치동 1293',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6436963, 34.810578]},
#  {'place': '전남 여수시 산단중앙로 145전북 군산시 비응도동 31',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6700512, 34.8322216]},
#  {'place': '전북 군산시새만금산업단지내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5870503, 35.9474649]},
#  {'place': '경북 청송군 현서면무계리 산 11',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.987596, 36.2210961]},
#  {'place': '강원도 평창군 미탄면회동리,평안리정선군 정선읍 회동리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4849847, 37.3761593]},
#  {'place': '경기도 포천시 신북면신평리 220-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2280342, 37.9580262]},
#  {'place': '경기도 안산시 단원구초지동 661',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7994948, 37.2979683]},
#  {'place': '경북 구미시 공단2동291',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3724286, 36.0970442]},
#  {'place': '충청남도 부여군 장암면석동리 산42-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8920177, 36.240187]},
#  {'place': '충북 단양군 매포읍매포리 270',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3341036, 37.0156586]},
#  {'place': '시흥 장현 목감지구내일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8572641, 37.3845831]},
#  {'place': '경기도 시흥시 정왕동1771-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7172871, 37.3628905]},
#  {'place': '경남 거제시 일운면소동리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.6859815, 34.8412498]},
#  {'place': '전남 신안군 자은면백산리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.0100859, 34.8772532]},
#  {'place': '충북 제천시 송학면입석리 289',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3019418, 37.2051238]},
#  {'place': '전남 고흥군 금산면어적리 264',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1418022, 34.4435042]},
#  {'place': '전남 고흥군 대서면남정리 2431-26',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.242915, 34.7674097]},
#  {'place': '경북 경주시 강동면왕신리 산46-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3124967, 35.9625481]},
#  {'place': '경북 경주시 천북면화산리 1180-21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2785236, 35.93498700000001]},
#  {'place': '충남 천안시 청당동청수8로 54',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1603383, 36.7878755]},
#  {'place': '광주광역시광주전남혁신도시내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8526012, 35.1595454]},
#  {'place': '충남 당진군 송악면부곡공단로 241',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7813551, 36.9571468]},
#  {'place': '경기도 화성시 장안면노진리 16',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8199324, 37.0544233]},
#  {'place': '인천시 서구 원창동437-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6090037, 37.5084604]},
#  {'place': '대구시 달성군 하빈면동곡리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4152721, 35.8680476]},
#  {'place': '강원도 정선군 고한읍고한리 산216-1 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8839494, 37.1828442]},
#  {'place': '경기도 남양주시별내3로 391 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1147453, 37.6669626]},
#  {'place': '충남 당진군 석문면삼봉리, 고대면 성산리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5680393, 36.9803517]},
#  {'place': '전북 군산시 소룡동53-8 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6401594, 35.977753]},
#  {'place': '경기도 안산시 단원구초지동 672',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.794652, 37.2954745]},
#  {'place': '강원도 강릉시 강동면대동리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9541928, 37.7280308]},
#  {'place': '경남 고성군 하이면덕호리 880번지 외',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1164472, 34.9149767]},
#  {'place': '경남 진주시 이반성면장안리 1081-2외 38필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.337188, 35.1913692]},
#  {'place': '경북 청송군 현서면무계리 산11번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.987596, 36.2210961]},
#  {'place': '충남 아산시 인주면금성리 123',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8731324, 36.8453593]},
#  {'place': '경남 거창군 신원면덕산리 산57번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.9162229, 35.592114]},
#  {'place': '전남 나주시 영산동 664-1292필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7457833, 35.0046214]},
#  {'place': '경기도 여주군 북내면외룡리 366',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6583791, 37.3615969]},
#  {'place': '전북 군산시 외항로1222',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5381948, 35.9543892]},
#  {'place': '전남 해남군 송지면학가리 324-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5055214, 34.3993809]},
#  {'place': '전남 신안군 비금면구림리 39-10',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [125.9489141, 34.7580286]},
#  {'place': '경기도 하남시 학암동 일원(사업지구 내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1616155, 37.4776989]},
#  {'place': '울산시 남구 횡성동처용로 718 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3562888, 35.4647551]},
#  {'place': '전남 무안군 운남면연리 및 성내리 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3359034, 34.9544622]},
#  {'place': '충남 당진시 석문면난지도리 183 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4335439, 37.051032]},
#  {'place': '강원도 삼척시 적노동일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1770184, 37.4147184]},
#  {'place': '전북 부안군 위도 및전남 영광군 안마군도',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5119874, 35.2771719]},
#  {'place': '경남 통영시 광도면 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4068799, 34.8996122]},
#  {'place': '경기도 포천시 신북면계류리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1766576, 37.9499243]},
#  {'place': '울산시 남구 매암동 29',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3830042, 35.5106347]},
#  {'place': '서울시 강서구 양천로201번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8263719, 37.5804823]},
#  {'place': '경기도 안양시 동안구부림로 100',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9669263, 37.3941135]},
#  {'place': '전남 신안군 자은면백산리 271번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [125.9974536, 34.8779107]},
#  {'place': '전남 해남군 화원면 구림리일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3135973, 34.7367405]},
#  {'place': '충남 서산시 대산읍기은리 628-6 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3804953, 36.9776181]},
#  {'place': '제주시 애월읍 어음리산 68-4번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3624805, 33.3843631]},
#  {'place': '경북 봉화군 봉성면외삼리 산124외 12필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7861061, 36.9039601]},
#  {'place': '세종시 부강면 부강리산23 육군종합보급창고',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3758169, 36.5336931]},
#  {'place': '전남 나주시 영산동664-1 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7464887, 35.0046287]},
#  {'place': '전남 나주시 영산동664-1 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7464887, 35.0046287]},
#  {'place': '전남 나주시 영산동664-1 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7464887, 35.0046287]},
#  {'place': '울산광역시 울주군서생면 신암리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3169375, 35.3486589]},
#  {'place': '충남 서천군 마량리일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4973423, 36.1409666]},
#  {'place': '울산시 울주군 온산읍신암리 360',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3445913, 35.4423929]},
#  {'place': '경북 고령군 다산면송곡리 1049-2,3번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3861703, 35.7933228]},
#  {'place': '충남 예산군 삽교읍1-21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7393823, 36.6878955]},
#  {'place': '경남 진주시 이반성면장안리 1081-2외38필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.337188, 35.1913692]},
#  {'place': '전남 영암군 삼호읍삼포리 1949번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3902632, 34.7398737]},
#  {'place': '충남 당진시 신평면매산리 164-8',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7948823, 36.9157102]},
#  {'place': '강원도 강릉시 강동면임곡리 외',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9612013, 37.6641691]},
#  {'place': '강원도 태백시 하사미동산 220-3 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.990465, 37.292041]},
#  {'place': '충남 논산시 은진면시묘리 470-1외 11필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1323682, 36.1418325]},
#  {'place': '서울시 강동구 강일동227-1외',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1660937, 37.5683886]},
#  {'place': '전북 전주시 덕진구팔복로 59',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0985108, 35.8483399]},
#  {'place': '강원도 춘천시 동산면봉명리(동춘천산업단지)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.777106, 37.76696099999999]},
#  {'place': '인천시 남구 도화동 825',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6605786, 37.4803113]},
#  {'place': '강원도 삼척시 동양길20(사직동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1762952, 37.4259827]},
#  {'place': '대구시 달성군 논공읍본리리 29-55 산단내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4601957, 35.7406053]},
#  {'place': '전남 완도군 신지면월양리 산20-1일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.849492, 34.3160841]},
#  {'place': '전남 영광군 백수읍상사리 및 하사리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3558487, 35.2625367]},
#  {'place': '전남 영광군 백수읍 약수리및 지산리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3954744, 35.2715903]},
#  {'place': '강원도 평창군 대관령면횡계리 산1-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7209909, 37.7031357]},
#  {'place': '전남 고흥군 대서면남정리 2431 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.242915, 34.7674097]},
#  {'place': '서울시 강동구 고덕동35-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1634514, 37.5683014]},
#  {'place': '전북 군산시새만금산업단지 내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5870503, 35.9474649]},
#  {'place': '대구혁신도시',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.601445, 35.8714354]},
#  {'place': '경기도양주신도시(옥정.회천)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0921414, 37.8219239]},
#  {'place': '전남 여수시여수산단4로 58',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6862811, 34.8341834]},
#  {'place': '충남 아산시 배방읍 장재리672-1번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0915493, 36.7989443]},
#  {'place': '충남 태안군 안면읍중장리 425-60 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3832622, 36.4866369]},
#  {'place': '충남 부여군 세도면사산리 594 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9506547, 36.2133201]},
#  {'place': '충남 서산시 해미면언암리 514-3 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4925246, 36.7261016]},
#  {'place': '충남 서산시 해미면언암리 500-1 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4939895, 36.7228554]},
#  {'place': '경기도 평택시 포승읍내기리 608-17',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8659301, 36.977222]},
#  {'place': '경북 영양군 영양읍무창리,무학리,기산리 및수비면 송하리 등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1882857, 36.6778522]},
#  {'place': '충남 아산시 배방읍장재리 672-1 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0915493, 36.7989443]},
#  {'place': '경남 양산시 상북면공원로 305-391 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0510193, 35.4140163]},
#  {'place': '경북 영양군 영양읍양구리, 석보면 홍계리',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.176671, 36.5995907]},
#  {'place': '부산 강서구르노삼성대로 61 지붕',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8760573, 35.0942462]},
#  {'place': '전남 영광군 염산면봉남리 1100번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3403742, 35.1989907]},
#  {'place': '강원도 강릉시 강동면임곡리 21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9906192, 37.6957382]},
#  {'place': '울산시 울주군 삼남면상천리 101-1일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1112252, 35.5283453]},
#  {'place': '세종시 장군면 봉안리160-13',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2272144, 36.496559]},
#  {'place': '경기도 파주시 월롱면덕은리 1271 건물지붕',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7700657, 37.810485]},
#  {'place': '대구시 서구 와룡로87길 92(이현동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.5335922, 35.8754384]},
#  {'place': '인천시 동구 송현3동147 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.642656, 37.4926237]},
#  {'place': '경기도 광명시 자경로17',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8909804, 37.42296839999999]},
#  {'place': '경기도 하남시 풍산동113-19일원 하남미사',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1864211, 37.5517187]},
#  {'place': '충남  부여군  양화면  송정리 산11,  산12-1,  185-1,    185-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8343199, 36.1348486]},
#  {'place': '충남  부여군  옥산면  상기리 산49-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7184591, 36.2268137]},
#  {'place': '충남  부여군  홍산면  상천리 산70-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7504424, 36.2423212]},
#  {'place': '전남  해남군  황산면  원호리 435-92,435-98',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4875799, 34.569675]},
#  {'place': '전남  곡성군  겸면  곡순로 1672번지  32-36(상덕리    515)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1917635, 35.2596267]},
#  {'place': '전남  보성군  보성읍  봉산리, 옥평리,  득량면  정흥리    일대(봉화산일대)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1255443, 34.7470393]},
#  {'place': '경북  울진군  기성면,  원남면 현종산  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4038889, 36.8630556]},
#  {'place': '경북  김천시  공단3길  64(응명동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1311698, 36.1525931]},
#  {'place': '경기  평택시  포승읍  남양만로 175-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7981862, 37.0072973]},
#  {'place': '강원  원주시  문막읍  원문로 2047(반계리    2262-5,6,7)일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7844132, 37.27574140000001]},
#  {'place': '경북  구미시  임수로  24번길 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4041758, 36.1137531]},
#  {'place': '경기  안산시  단원구  첨단로 267번길  31',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7518342, 37.3066276]},
#  {'place': '전남  영광군  법성면  입암리 산34번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4506211, 35.3334935]},
#  {'place': '울산시  북구  대안동  산288-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.381803, 35.6373204]},
#  {'place': '강원  고성군  간성읍  흘리  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3826076, 38.2684351]},
#  {'place': '전남  신안군  자은면  고장리 산224-13  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.0138548, 34.9068822]},
#  {'place': '인천시  남구  학익동  723번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.669278, 37.4380623]},
#  {'place': '인천시  남구  학익동  723번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.669278, 37.4380623]},
#  {'place': '인천시  남구  학익동  723번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.669278, 37.4380623]},
#  {'place': '전남  해남군  황산면  한자리 23-4외  7필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4533585, 34.5404768]},
#  {'place': '전남  해남군  황산면  한자리 23-11외  3필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4603158, 34.5411443]},
#  {'place': '충남  태안군  안면읍  창기리 209-328,  209-330번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3665878, 36.5890999]},
#  {'place': '서울시  강서구  마곡동  72',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8316893, 37.5742712]},
#  {'place': '전남  보성군  미력면  덕림리 산13-3(임),  4-1(전)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1173911, 34.7935488]},
#  {'place': '울산시  북구  대안동  산288-1, 산79,  산78-1,  산78',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.381803, 35.6373204]},
#  {'place': '경북  포항시  남구  호동  39-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3922316, 35.9834386]},
#  {'place': '서울시  마포구  양화로  151(동교동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9228523, 37.5578024]},
#  {'place': '충남  서천군  서면  신합리 311-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5548403, 36.1423411]},
#  {'place': '충남  보령시  성주면  개화리 산30',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6444146, 36.3019595]},
#  {'place': '충남  보령시  성주면  개화리 산30',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6444146, 36.3019595]},
#  {'place': '경기  양주시  남면  상수리 247,  247-1,  247-2,    248, 248-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9955971, 37.8632735]},
#  {'place': '전북  군산시  비응도동  21,  19, 22,  23,    24,,35번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5290799, 35.9502782]},
#  {'place': '강원도  평창군  대관령면  횡계리  산178,  188-1,    188-10, 188-11,  1-134',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7209909, 37.7031357]},
#  {'place': '전북  남원시  광치동  산7번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.388053, 35.4417872]},
#  {'place': '충남  부여군  은산면  가중리 산10-26',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8399033, 36.3047454]},
#  {'place': '경기  양주시  남면  상수리  산112-11,  산113',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9775128, 37.8708033]},
#  {'place': '경기  양주시  남면  상수리  산112-11',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9775128, 37.8708033]},
#  {'place': '경기  양주시  남면  상수리  산112-11',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9775128, 37.8708033]},
#  {'place': '경기  포천시  신북면  청신로 1897(신평리  480-3번지)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2045068, 37.9386342]},
#  {'place': '광주광역시  광산구  수완동 1149',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8297814, 35.19685190000001]},
#  {'place': '광주  서구  치평동 766-2 번지  외  28필지   광주제1하수종말처리장  구조물  상부',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8299501, 35.1575799]},
#  {'place': '충남  서산시  고북면  신정리 726-19외 9필지(건물 7동   포함)  (해미비행장內)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4953374, 36.6889275]},
#  {'place': '전남  여수시  율촌면  율촌 제1산업단지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.578106, 34.8996486]},
#  {'place': '충북  청주시  청원구  북이면 신대석성로  253-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5192529, 36.7464716]},
#  {'place': '충남  서천군  장항읍  원수리 450-12번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7221482, 36.0087855]},
#  {'place': '경북  영양군  영양읍  무창리 산62-36,  3-2,  110,  108',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2164881, 36.6180468]},
#  {'place': '포항시  북구  신광면  냉수리 산63,  62,  61,  17,  16-1,  16, 15,  14,  8,  7,  흥해읍    매산 리  산84,  82,  흥해읍  학천리  산1-13',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2754707, 36.0854411]},
#  {'place': '경남남해군서면노구리산98,산99-2번지남상리산60-2,산60-3번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.850141, 34.8546853]},
#  {'place': '제주특별자치도  제주시  구좌읍  덕천리  산  82',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7356547, 33.4806289]},
#  {'place': '강원  정선군  고한읍  고한리 산216-1  등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8839494, 37.1828442]},
#  {'place': '부산시  기장군  정관면  산단1로  83',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1783001, 35.3148842]},
#  {'place': '부산시  기장군  정관면  산단1로  83',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1783001, 35.3148842]},
#  {'place': '부산시  강서구  화전산단1로  63번길  10(화전동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.875261, 35.1016291]},
#  {'place': '전남  화순군  도암면  우치리 산89-1,  청풍면  백운리  산132-1,  이만리  산165',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.918017, 34.8701236]},
#  {'place': '강원  태백시  통동  산69,  황지동  산173-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9789425, 37.1867588]},
#  {'place': '강원  평창군  봉평면  진조리 산80-1,  횡성군  둔내면  삽 교리  산1-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3061851, 37.5610736]},
#  {'place': '경남  통영시  광도면  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4068799, 34.8996122]},
#  {'place': '강원  강릉시  옥계면  산계리 8번지(라파즈한라시멘트  공장부지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.008498, 37.589326]},
#  {'place': '서울시  마포구  상암동 481-6(월드컵공원내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8935007, 37.5638735]},
#  {'place': '전남  여수시  여수국가산단 내(여수산단2로  46-51,  월하동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6607226, 34.8091104]},
#  {'place': '경남  산청군  신등면  모례리 산78-1,  산청읍  범학리  산31,  척지리  산134',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.9547734, 35.3942834]},
#  {'place': '경남  산청군  신등면  율현리 산166,  산169,  척지리  산17',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.9525195, 35.4213444]},
#  {'place': '경북  청송군  안덕면  노래리 산68-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0077296, 36.3755631]},
#  {'place': '충남  천안시  청당동  청수8로  56번길',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1613093, 36.7870828]},
#  {'place': '전남  장흥군  해당리  장흥 바이오  식품산업단지내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9370673, 34.6919321]},
#  {'place': '경남  양산시  상북면  내석리 산237,  산238,  산239',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.994729, 35.4417093]},
#  {'place': '경 남 산 청 군 금 서 면 특 리 산79-1,산79-2,자혜리산7-1일대',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.0098139, 35.010101]},
#  {'place': '전남  강진군  도암면  석문리 산  215,  산194-3  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7111629, 34.5310617]},
#  {'place': '경북  김천시  어모면  산업단지로  39번지  공장지붕',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.116879, 36.161571]},
#  {'place': '경북  김천시  어모면  옥계리 산214번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.0787591, 36.2301746]},
#  {'place': '전북  남원시  광치동  산51-1외  9필지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3956179, 35.46593]},
#  {'place': '경북  울진군  북면  울진북로 2040',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3730611, 37.09877]},
#  {'place': '울산시  남구  장생포로  285번길',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3739645, 35.5140251]},
#  {'place': '충남  청양군  정산면  역촌리 701-1,  703-1,  705-3번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9498301, 36.4209824]},
#  {'place': '부산광역시  해운대구  해운대로  896',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1848351, 35.1739926]},
#  {'place': '전남  무안군  청계면  영산로 1958-98',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4398904, 34.9299467]},
#  {'place': '경남  함안군  대산면  부목리 169',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4694479, 35.36249980000001]},
#  {'place': '전남  신안군  압해면  가룡리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.301154, 34.9066445]},
#  {'place': '전남  장성군  삼계면  부성리 산129-3,  산129-2,  신기리 산141-2,  화산리  산136-1, 산137-8,    삼서면  학성리  산96-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6130309, 35.299998]},
#  {'place': '전남  고흥군  호형리  산126, 산127,  산128,  산129,  산171-1,  산171-3,  산171-4, 산171-5,  산171-6,  등암리 산6,  포두면  봉림리  산34, 산36,  산36-1,  산130-1,  풍양면  율치리  산151',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3065763, 34.5785116]},
#  {'place': '울산시  울주군  온산읍  원산로  59',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3499243, 35.4123051]},
#  {'place': '충남  홍성군  구항면  지정리 107-11,  산24',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.638396, 36.5519987]},
#  {'place': '강원  고성군  수동면,  현내면, 간성읍,  거진읍  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4525014, 38.4362262]},
#  {'place': '전북  군산시  새만금  매립지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.587035, 35.9474822]},
#  {'place': '제주시  삼양동  900번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.596692, 33.5056199]},
#  {'place': '부산시  강서구  명지동 607-641',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9063123, 35.1130958]},
#  {'place': '경북  안동시  길안면  백자리 산97번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8661746, 36.3907017]},
#  {'place': '경기  평택시  고덕면  해창4길  64-15  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0131919, 37.0272752]},
#  {'place': '충북  청주시  흥덕구  옥산면 호죽리  907외908',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3725868, 36.702395]},
#  {'place': '제주  제주시  월산남길  312(해안동)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4718292, 33.4475848]},
#  {'place': '강원  횡성군  횡성읍  조곡리 3-2번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.0293088, 37.4947916]},
#  {'place': '경북  영천시  고경면  상계로 178-18',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0996058, 36.0055718]},
#  {'place': '경기  화성시  송산면  마산리 416-15번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.6779365, 37.225302]},
#  {'place': '강원  태백시  창죽동  9-167외  8필지  화전동  143-26외 1필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9602141, 37.2236723]},
#  {'place': '전남  신안군  압해면  가룡리 일원(해상  포함)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.301154, 34.9066445]},
#  {'place': '전남  여수시  여수산단로  남해화학  부지  내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.75078, 34.8528969]},
#  {'place': '강원  정선군  고한읍  고한리 산216-1  등지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8839494, 37.1828442]},
#  {'place': '충북  천안시  서북구  차암동 14-4  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1151654, 36.8575236]},
#  {'place': '전북  군산시  비응도동  36',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5341796, 35.9480587]},
#  {'place': '경기  양주시  옥정동  840-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0793277, 37.8164517]},
#  {'place': '전남  장흥군  부산면  지천리 산22',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9062972, 34.76421670000001]},
#  {'place': '전남  해남군  송지면  통호리 산  98  등  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5524058, 34.334182]},
#  {'place': '경북  포항시  남구  오천읍 진전리  산88-1번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4039238, 35.8669399]},
#  {'place': '전남  목포시  대양동  797번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3984875, 34.8338694]},
#  {'place': '대구시  동구  율암동  산5번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.6989164, 35.88592430000001]},
#  {'place': '광주시  서구  매월1로  50-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8552691, 35.1109797]},
#  {'place': '경북  포항시  남구  장기면 두원리  산162임,  산162-1임, 산162-2임,  계원리  산87  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4954784, 35.85525]},
#  {'place': '강원  철원군  근남면  육단리 산88-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5162673, 38.2200201]},
#  {'place': '경북  김천시  대광동  797번지  일대',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1440719, 36.1371455]},
#  {'place': '전남  무안군  운남면  내리 산39번지,  714-5,  711-29, 산50,  산41-1,  산107-8',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3122803, 34.9861732]},
#  {'place': '경남  양산시  원동면  대리 산90-1,  산16-1,  선리  산1-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9846345, 35.457992]},
#  {'place': '경북  군위군  고로면  화북리 산229-1,  1254-4,5,6,  영천시 신녕면  화남리  산64/가천리   산18-1,산23',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7772619, 36.1003197]},
#  {'place': '제주시  한림읍  금악리  산23번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3461914, 33.3489594]},
#  {'place': '경북  청송군  현서면  무계리 산11번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.987596, 36.2210961]},
#  {'place': '여주시  강천면  강천로  121(적금리  46)  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7171754, 37.2551337]},
#  {'place': '충남  서천군  장항읍  장항공단길  28번길  60',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7221482, 36.0087855]},
#  {'place': '충북  청주시  흥덕구  화계동 29-15(LG화학  청주공장內)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.4408391, 36.6518765]},
#  {'place': '부산시  강서구  국제물류도시  일반산업단지  1단계  제2공구  122-7Lot',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9805666, 35.2122157]},
#  {'place': '광주시  서구  치평동  764-2번지  외  6필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8288107, 35.1588903]},
#  {'place': '강원  고성군  토성면  도원리 산1  외  6필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4463953, 38.2699552]},
#  {'place': '경북  영천시  화북면  정각리 산6-1,  산218-3,  포항시  죽장면  두마리  산84,  85,  98, 99  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9861839, 36.1583524]},
#  {'place': '경북  포항시  남구  구룡포읍 석병리  산62번지  외  12필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.5582378, 36.021601]},
#  {'place': '전남  영광군  백수읍  하사리,약수리,  염산면  축동리,신성리,송암리  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3558487, 35.2625367]},
#  {'place': '경북  포항시  남구  호미곶면 강사리  산199-1일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.5494377, 36.0330144]},
#  {'place': '강원도  양양군  현남면  하월천리  산1-1번지,  상월천리 산1-1번지,  현북면  어성전리 산2번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7038652, 37.9132061]},
#  {'place': '충남  아산시  인주면  금성리 산  45',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8761849, 36.843786]},
#  {'place': '전남  광양시  광양읍  세풍리 2200',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5877061, 34.9358814]},
#  {'place': '충북  충주시  금가면  월상리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8700852, 37.036753]},
#  {'place': '경기도  평택시  포승읍  평택항로156번길  43',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8483984, 36.9755417]},
#  {'place': '전남  광양시  황금동  산  191, 황금일반산업단지  內',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6155371, 34.9142315]},
#  {'place': '경기도  평택시  포승읍  원정 리  1173-7',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8852807, 36.982824]},
#  {'place': '전북  군산시  새만금  4호방조제  내측  일부',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.482758, 35.820222]},
#  {'place': '경북  군위군  고로면  석산리 산19번지  일원,  의성군  춘산면  신흥리  산70번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8714507, 36.2009442]},
#  {'place': '광주시  광산구  신창동  10-8',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8548358, 35.1943179]},
#  {'place': '광주시  광산구  수완로  130(수완동  1149번지)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8297814, 35.19685190000001]},
#  {'place': '경남  함안군  군북면  장지리 1407',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3411532, 35.2858864]},
#  {'place': '충북  음성군  대소면  대풍리 259-2번지  (CJ헬스케어  대소공장  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.4594926, 36.9835246]},
#  {'place': '대구시  서구  이현동  산  117 번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.533509, 35.8787169]},
#  {'place': '경북  문경시  신기공단2길 37  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1734948, 36.6351007]},
#  {'place': '경남  양산시  원동면  대리 산90-2번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9847647, 35.4517671]},
#  {'place': '경남  양산시  동면  법기리 산1-1,  산1-3,  산14-1,  호계동  산69-1  번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1100822, 35.3792888]},
#  {'place': '경북  경주시  산내면  내일리 763-1,산421-3번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0772673, 35.74323589999999]},
#  {'place': '경북  영양군  청기면  구매리 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0129844, 36.6627206]},
#  {'place': '충북  음성군  맹동면  봉현리 22-6외  2필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5417032, 36.9548081]},
#  {'place': '충북  단양군  매포읍  우덕리 360번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3197171, 37.0247809]},
#  {'place': '대구시  달성군  논공읍  본리리 29-55번지  및  1023번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4601957, 35.7406053]},
#  {'place': '경남  고성군  삼산면  병산리 532-1외  5필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.2914564, 34.9505696]},
#  {'place': '강원도  삼척시  도계읍  황조리 산159임  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1032243, 37.2245719]},
#  {'place': '강원도  삼척시  하장면  어리 산66번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9410834, 37.2879517]},
#  {'place': '강원도  태백시  소도동  산78, 화전동  산47-61,  황지동    산176-1,14,16,  창죽동  산1-1,  혈동  산57',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9357453, 37.1951132]},
#  {'place': '전북  고창군  상하면  용정리 1626번지외  27필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.45575, 35.4662909]},
#  {'place': '강원도  평창군  봉평면  유포리 산200번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3393122, 37.5229884]},
#  {'place': '바이오 인천시 서구 오류동 1537번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5949909, 37.58468269999999]},
#  {'place': '경기도  화성시  남양읍  매바위로  570-10',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.804204, 37.1553024]},
#  {'place': '경기도  양주시  은현면  은남로 160',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0095212, 37.8931512]},
#  {'place': '충남  서산시  대산읍  죽엽로 397일원(대죽리)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4003556, 36.9830054]},
#  {'place': '경북  포항시  북구  죽장면  상옥리  산20,  산15-1,  산15-2, 기북면  성법리  산1,  산2,  신광면  마북리   산2-1,  산12번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.214879, 36.2136872]},
#  {'place': '강원도  평창군  용평면  노동리 산1-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4445405, 37.7071256]},
#  {'place': '전남  고흥군  동강면  대강리 1219-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.301171, 34.7995899]},
#  {'place': '경북  영덕군  남정면  중화리 산71-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3275572, 36.359231]},
#  {'place': '경북  포항시  북구  죽장면  가사리  산2-1,석계리  산1-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1799187, 36.2198634]},
#  {'place': '전남  여수시  중흥동  1724번지(여수국가산업단지內)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6813647, 34.8252381]},
#  {'place': '전남  여수시  화정면  백야리 산253번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6341839, 34.616412]},
#  {'place': '경북  영천시  자양면  용산리 산31번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0279902, 36.1178214]},
#  {'place': '강원도  평창군  용평면  도사리 산1번지,속사리  산270번지,  덕거리  산1번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4405799, 37.64822170000001]},
#  {'place': '강원도  삼척시  하장면  중봉리 산1,  도계읍  무건리  산58,  도계읍  황조리  산159,  도계읍 신리  산138,    삼척시  노곡면 주지리  산9,  노곡면  상마읍리 산104,  삼척시  원덕읍  이천리 산322,  삼척시  가곡면  오목리 산21번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9386011, 37.4076278]},
#  {'place': '광주시  서구  치평동  762-2번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8288184, 35.1596556]},
#  {'place': '충남  서산시  대산읍  독곶2로 103(한화토탈  대산공장  內)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.351237, 36.9916989]},
#  {'place': '충북  청주시  청원군  북이면 신대석성로  253-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5192529, 36.7464716]},
#  {'place': '경북  영천시  화북면  정각리 산150-1번지  일원',
#   'geometry.type': 'Point',
# ...
#  {'place': '충남  아산시  둔포면  염작리  92-28',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0756659, 36.9032994]},
#  {'place': '충남  아산시  둔포면  염작리  92-28',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0756659, 36.9032994]},
#  {'place': '충북  충주시  대소원면  영평리  757,  760',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8168014, 36.9911266]},
#  {'place': '충북  보은군  삼승면  우진리(보은산업단지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7328376, 36.4240364]},
#  {'place': '충남  당진시  석문면  산단4로  341(석문국가산업단지 내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5826074, 36.9858765]},
#  {'place': '충남  당진시  합덕읍  석우리  1222',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7327385, 36.7905377]},
#  {'place': '부산광역시  강서구  범방동 1911-8(일반산업단지內)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8827018, 35.1660756]},
#  {'place': '경기도  파주시  탄현면  낙하리  55-21',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7349608, 37.8357622]},
#  {'place': '경기도  파주시  문산읍  운천리  4-5',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7913404, 37.8840197]},
#  {'place': '전남  순천시  해룡면  호두리  1201-10(해룡일반산업단지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5619774, 34.8996473]},
#  {'place': '전남  순천시  해룡면  호두리  1201-9(해룡일반산업단지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5619774, 34.8996473]},
#  {'place': '강원도  고성군  죽왕면  가진리  산47번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4986567, 38.3671464]},
#  {'place': '전남  완도군  약산면  관산리,  우두리  등  176필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.8896786, 34.3793858]},
#  {'place': '충남  당진시  석문면  초락도리  966번지  외  510필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4819087, 37.0093804]},
#  {'place': '충남  당진시  석문면  초락도리  1672번지  외  257필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4940665, 36.983597]},
#  {'place': '강원도  태백시  동점동  동 점산업단지  블록  3-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0509505, 37.0942103]},
#  {'place': '경북  영덕군  영덕읍  매정리  1162번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4057461, 36.4540751]},
#  {'place': '경북  영덕군  영덕읍  매정리  1162번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4057461, 36.4540751]},
#  {'place': '전남  목포시  대양동 1181-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4014369, 34.8325814]},
#  {'place': '전남  목포시  대양동 1181-5',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4014369, 34.8325814]},
#  {'place': '전북  부안군  위도  남쪽  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2827, 35.597678]},
#  {'place': '전남신안군임자면북서쪽공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.111226, 35.08416450000001]},
#  {'place': '전남  완도군  금일읍  사동리  남쪽  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0845021, 34.3258269]},
#  {'place': '경남  밀양시  하남읍  양동리  835-1,  밀양하남일반산업단지  내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7244618, 35.3839605]},
#  {'place': '전남신안군자은도북서쪽공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.046462, 34.8852314]},
#  {'place': '전남  신안군  자은도  서쪽 공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.046462, 34.8852314]},
#  {'place': '전남  신안군  안좌면  내호리  653번지  외  60필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.0832323, 34.7407959]},
#  {'place': '충남  아산시  둔포면  염작리  92-28',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0756659, 36.9032994]},
#  {'place': '경북  포항시  남구  대송면 대각리  산168-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3717012, 35.9442848]},
#  {'place': '강원도  태백시  장성동  산3-2  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0043589, 37.1144158]},
#  {'place': '전남  목포시  대양동 1182-2(대양일반산업단지 50블록)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4014369, 34.8325814]},
#  {'place': '전남해남군문내면무고리인근공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3083924, 34.627737]},
#  {'place': '충남태안군근흥면석도/난도중간북방해상',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2280145, 36.7136234]},
#  {'place': '충남  아산시  둔포면  관대리  53-12번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0352494, 36.9081281]},
#  {'place': '경기  용인시  처인구  포곡읍  금어리  16번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.271115, 37.2973215]},
#  {'place': '전남  신안군  증도면  대초리  1653번지  외  10필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.1711854, 34.9832336]},
#  {'place': '경북  문경시  신기동  942번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1736957, 36.63941810000001]},
#  {'place': '충남  천안시  동남구  목천읍  소사리  141-3,  137-6, 145-7',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.1716712, 36.7368404]},
#  {'place': '충남  금산군  추부면  신평리  873-16',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.4968915, 36.2282452]},
#  {'place': '부산광역시  금정구  회동동 555-4',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.1119505, 35.2214073]},
#  {'place': '전북  군산시  비응도동 36-23(군산2국가산업단지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5341796, 35.9480587]},
#  {'place': '경남  함안군  법수면  강주리  1360-3  일원(군북일반 산업단지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3303257, 35.3131101]},
#  {'place': '강원도  삼척시  도계읍  점리  산47,  산44-2,  늑구리 산242',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0223159, 37.270982]},
#  {'place': '강원도  정선군  백전리  산272번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8459593, 37.2649062]},
#  {'place': '충남  태안군  원북면  방갈리  796번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.2225956, 36.8782698]},
#  {'place': '강원도  강릉시  강동면  임곡리  산25번지(강릉시자원순환센터  부지  내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9869002, 37.6880603]},
#  {'place': '강원도  태백시  동점동  동점산업단지  블록  3-4(태백시  동점산업단지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0464035, 37.0845505]},
#  {'place': '경북  경주시  강동면  왕신리  산36,  37',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3064795, 35.9669317]},
#  {'place': '전남  여수시  월내동  280, 1393',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7345827, 34.8533747]},
#  {'place': '전남 여수시 묘도동 2016',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7392027, 34.8808591]},
#  {'place': '경북  포항시  남구  오천읍 갈평리  산272번지,  진전리 산127번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.389024, 35.9013893]},
#  {'place': '강원도  삼척시  도계읍  점리  산182-1,  흥전리  산92-1,  전두리  산67번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0054032, 37.24172]},
#  {'place': '경남  함안군  가야읍  사내리  1254(사내일반산업단지 내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3750314, 35.2714244]},
#  {'place': '전남  강진군  신전면  용화리  129-3  등  (25필지)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7126303, 34.4829648]},
#  {'place': '전남  여수시  거문도  동측 20km  공유수면(문섬인근)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3183346, 34.0485456]},
#  {'place': '경기도  양주시  남면  삼일로485번길  67-22',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9863985, 37.8616089]},
#  {'place': '경북  봉화군  명호면  관창리  산60-2,  산60-3,  산166, 산170,  산175-4,  산186,  산198',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8364784, 36.8267892]},
#  {'place': '광주  광산구  연산동  평동3차  일반산업단지  산업  7-7블록',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.741426, 35.114326]},
#  {'place': '충남  당진시  송악읍  금곡리  322-9  포함  6필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7288521, 36.9195779]},
#  {'place': '울산  울주군  온산읍  방도리  583',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3353779, 35.4431774]},
#  {'place': '경남  창원시  성산구  귀곡동  558',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.6057671, 35.1762968]},
#  {'place': '경기  안산시  단원구  첨단로  670',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.794652, 37.2954745]},
#  {'place': '울산시  남구  황성동  처용로  718  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3562888, 35.4647551]},
#  {'place': '경남통영시욕지면동항리좌사리도일원공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.260244, 34.637232]},
#  {'place': '전남  신안군  임자면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.111226, 35.08416450000001]},
#  {'place': '강원도  삼척시  원덕읍  산양리  산1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2833053, 37.1782745]},
#  {'place': '경북  울진군  울진읍  신림리  산234-1번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3395298, 36.9925291]},
#  {'place': '경북  포항시  남구  장기면 산서리  산255번지,  경주시 양북면  권이리  산2,  3번지 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4642917, 35.8742141]},
#  {'place': '울산광역시  남구  용잠로 623',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3829667, 35.4776466]},
#  {'place': '충남  보령시  오천면  오천 해안로  89-37  보령발전본부  내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4957874, 36.4026479]},
#  {'place': '전남  여수시  삼산면  초도리  일원  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2386939, 34.2267913]},
#  {'place': '경북  봉화군  춘양면  우구치리  산1-70,  산1-19',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7810628, 37.0519353]},
#  {'place': '강원도  삼척시  근덕면  매원리  산75,  산82,  산184, 산288',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.2894317, 37.2946775]},
#  {'place': '울산  동측  60km  앞  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3113596, 35.5383773]},
#  {'place': '경기  화성시  향남읍  방축리  467',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9212463, 37.1151401]},
#  {'place': '경기  용인시  처인구  남동 524-5,  530-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2000933, 37.22095890000001]},
#  {'place': '경기  이천시  설성면  자석리  135',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.5692598, 37.1705738]},
#  {'place': '강원  영월군  북면  마차리 산1-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4764527, 37.2729055]},
#  {'place': '강원도  고성군  현내면  마달리  산3번지,  산5번지,  철통리  산63번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4036683, 38.5159685]},
#  {'place': '강원도  고성군  간성읍  교동리  산2,  산3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4511443, 38.3855469]},
#  {'place': '경남  하동군  금남면  대송리  대송산업단지  A9-2',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.8520885, 34.9764065]},
#  {'place': '전북  익산시  낭산면  용기리  1946',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.9879187, 36.0547774]},
#  {'place': '울산  남구  여천동  321',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3583347, 35.5192323]},
#  {'place': '경북  포항시  북구  청하면 명안리  산24번지  외7필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.300242, 36.1810242]},
#  {'place': '충북  음성군  음성읍  한벌리  산52,  산54-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6998164, 36.9490337]},
#  {'place': '울산광역시  울주군  삼남읍 상천리  427-130,  427-474, 427-527,  427-174, 427-251,    427-478',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.106335, 35.5276079]},
#  {'place': '경북  영덕군  영덕읍  매정리  1161번지  일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.4062801, 36.454368]},
#  {'place': '경남  거제시  연초면  오비리  산6-2번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.6148396, 34.9174717]},
#  {'place': '강원도  태백시  동점동  동점산업단지  블록  3-6(동점산업단지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0464035, 37.0845505]},
#  {'place': '충남  서산시  대산읍  대죽리  640-6  현대오일뱅크  대산공장',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4019857, 37.000816]},
#  {'place': '인천시  중구  용유동',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4024178, 37.44384489999999]},
#  {'place': '전남  진도군  조도면 가사도리  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.0486598, 34.4815801]},
#  {'place': '울산  울주군  청량읍 상개로 63-76',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3177583, 35.4891407]},
#  {'place': '경북  안동시  상아동 산3-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.7449683, 36.5870676]},
#  {'place': '경북  의성군  옥산면 금봉리  산13,  산20, 산22',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.869459, 36.3381653]},
#  {'place': '제주도  서귀포시  표선면 가시리 3604 등 9개필지(3649, 3646, 3645,  3644,  3652-1,  3652-2, 3652-3, 3668-1)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7063341, 33.3988071]},
#  {'place': '전남  여수시  율촌면 신풍리 5-5번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6358983, 34.844466]},
#  {'place': '전남  여수시  율촌면 신풍리 5-6번지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.6360268, 34.8440815]},
#  {'place': '전남  영암군  삼호읍 난전리 1689-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.4216201, 34.7719718]},
#  {'place': '대구광역시 달서구 달서대로210(대천동774) 일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4982708, 35.8216855]},
#  {'place': '부산광역시 강서구 명지동 3043일원(부산 에코델타시티  집단에너지부지 내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.9077103, 35.1256951]},
#  {'place': '전남  여수시  남면  금오도 인근  해상',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.7359226, 34.5308016]},
#  {'place': '울산시  울산항  동측  58km 앞  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3734649, 35.5192983]},
#  {'place': '충남  태안군  고남면  장곡리  783-1외  6필지,  안면읍 중장리  2300-1외  13필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.3660499, 36.4427433]},
#  {'place': '충남  서산시  대산읍  독곶 2로  50',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.362671, 36.9959976]},
#  {'place': '경남  고성군  하이면  덕호리  889-6',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.1126122, 34.9131431]},
#  {'place': '전북  전주시  완산구  삼산길  51-70',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0732172, 35.7987616]},
#  {'place': '경기  화성시  송산면  사강리  256-2,  256-11',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7205918, 37.2189449]},
#  {'place': '충남  아산시  둔포면  관대리 53-3,4,5,9,10,12,14,122-9',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0350161, 36.9085714]},
#  {'place': '충남  보령시  주교면  관창리  1224-1  관창일반산업단지  내',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5742237, 36.3770996]},
#  {'place': '광주시  광산구  고룡동  산56-16',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.7804517, 35.2040844]},
#  {'place': '강원도  고성군  간성읍  금수리  산9-5,  9-6',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.4752538, 38.3705023]},
#  {'place': '경북  칠곡군  약목면  복성리  750',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.3584429, 36.0342674]},
#  {'place': '울산시 북구 효암로 84-13',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3666775, 35.5547591]},
#  {'place': '전남  여수시  삼산면  손죽리  역만도  일원    해상',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.3543852, 34.1732689]},
#  {'place': '전남  여수시  삼산면  초도리  일원    공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.2386939, 34.2267913]},
#  {'place': '울산시  동측  60km  앞  공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3113596, 35.5383773]},
#  {'place': '울산시동측60km앞공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3113596, 35.5383773]},
#  {'place': '울산동측63km앞공유수면',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.3113596, 35.5383773]},
#  {'place': '당진시 석문면 교로리  2304  외  117필지',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5047819, 37.0144574]},
#  {'place': '강원도  태백시  동점동  동 점산업단지  블록  3-3',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0509505, 37.0942103]},
#  {'place': '강원도 태백시 동점동 동점산업단지 블록 3-4(태백시 동점산업단지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0464035, 37.0845505]},
#  {'place': '강원도  태백시  동점동  동점산업단지  블록  3-6(동점산업단지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [129.0464035, 37.0845505]},
#  {'place': '전북  군산시 새만금산업단지  5공구 산-13일원',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [126.5870503, 35.9474649]},
#  {'place': '경기평택시고덕면해창리1278-1',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [127.0193638, 37.0274047]},
#  {'place': '강원도정선군사북읍사북리산155-38일원(하이원리조트부지내)',
#   'geometry.type': 'Point',
#   'geometry.coordinates': [128.8225339, 37.212986]},
#  ...]

# %%
mygeometry = {'place': "경기도 연천군 전곡읍 양연로 490", 'geometry.type': 'Point','geometry.coordinates': [127.00478125595711, 37.95086092180179]}
geometry_data.append(mygeometry)

# %%
len(geometry_data)
# Out:
# 1089

# %%
import json
with open('final_coords.json', 'w') as fp:
    json.dump(geometry_data, fp)
